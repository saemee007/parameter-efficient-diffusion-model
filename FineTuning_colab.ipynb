# %% [markdown]
# # Fine-tuning of Stable Diffusion models
#
# A notebook for training Stable Diffusion models using Dreambooth or Low-rank Adaptation (LoRA) approaches.
#
# Tested with [Stable Diffusion v1-5](https://huggingface.co/runwayml/stable-diffusion-v1-5) and [Stable Diffusion v2-base](https://huggingface.co/stabilityai/stable-diffusion-2-base).
#
# Stay up-to-date on [Github](https://github.com/brian6091/Dreambooth), and leave an [issue](https://github.com/brian6091/Dreambooth/issues) if you run into problems.
#
# [![Brian6091's GitHub stats](https://github-readme-stats.vercel.app/api?username=brian6091&hide=contribs&theme=onedark&show_icons=true)](https://github.com/brian6091/Dreambooth)
#
# [<a href="https://www.buymeacoffee.com/jvsurfsqv" target="_blank"><img src="https://cdn.buymeacoffee.com/buttons/v2/default-yellow.png" height="40px" width="140px" alt="Buy Me A Coffee"></a>](https://www.buymeacoffee.com/jvsurfsqv)

# %% [markdown]
# # Install dependencies (takes about 1 minute)

# %%
# %%capture
# !cd content/
# !git clone https://github.com/brian6091/Dreambooth --branch main --single-branch
# !pip install -r "Dreambooth/requirements.txt"
# !pip install -U --pre triton
# !pip install torchinfo

# !git clone https://github.com/brian6091/lora --branch v0.0.5 --single-branch
# !python -m pip install content/lora/

# %%
#@title xformers
#%%capture

# !nvidia-smi -L

# Tested with Tesla T4 and A100 GPUs
# !pip install xformers==0.0.16rc425
# May complain about some incompatibilities, which are resolved by upgrading the following:
#!pip install -U --pre torchvision
#!pip install -U --pre torchtext
#!pip install -U --pre torchaudio

# %% [markdown]
# # Which model to train from?

# %%
#@title ## Name or path to initial model and VAE
#@markdown Obligatory (e.g., runwayml/stable-diffusion-v1-5, stabilityai/stable-diffusion-2-base, or full path to model in diffusers format)
MODEL_NAME_OR_PATH = "runwayml/stable-diffusion-v1-5" #@param {type:"string"}

#@markdown Optional (e.g., stabilityai/sd-vae-ft-mse), leaving empty will default to VAE packaged with the model
VAE_NAME_OR_PATH = "" #@param {type:"string"}
#if VAE_NAME_OR_PATH=="":
#  VAE_NAME_OR_PATH = None

#@markdown (Not yet implemented), leaving empty will default to text encoder packaged with the model
TEXT_ENCODER_NAME_OR_PATH = "" #@param {type:"string"}

# %%
#@title ## Hugging Face 🤗 credentials

#@markdown If initiating training from official stable diffusion checkpoints (e.g., [stable-diffusion-v1-5](https://huggingface.co/runwayml/stable-diffusion-v1-5)), you must accept the license before using the model. You'll need a [🤗 Hugging Face](https://huggingface.co/) account to do so, after which you can [generate a login token](https://huggingface.co/settings/tokens) and paste it here.
from huggingface_hub import login

HUGGINGFACE_TOKEN = "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" #@param {type:"string"}
login(HUGGINGFACE_TOKEN)
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /home/saemeechoi/.cache/huggingface/token
# Login successful

# %%
# #@title ## Mount Google Drive if initial model stored there (or you want to direct outputs there)
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# # Set up experiment parameters

# %%
#@title ## Training parameters

import os
from IPython.display import Markdown as md

#@markdown Unique token for specific subject
INSTANCE_TOKEN= "raretoken" #@param{type: 'string'}

#@markdown Use image captions? Captions can be either the image filename, or a separate text file (that must be named identically to the image but w/ extension .txt). If a separate .txt file exists, filename is ignored.
USE_IMAGE_CAPTIONS = False #@param {type:"boolean"}
USE_IMAGE_CAPTIONS_FLAG = ""
if USE_IMAGE_CAPTIONS:
  USE_IMAGE_CAPTIONS_FLAG='--use_image_captions'

#@markdown Path to instance images. Filenames are irrelevant, unless images are captioned *and* captions are not separate textfiles, in which case INSTANCE_TOKEN should appear in relevant filenames as part of the caption.
INSTANCE_DIR="content/InstanceImages" #@param{type: 'string'}

RESOLUTION = 512 #@param{type: 'number'}

TRAIN_BATCH_SIZE = 1 #@param{type: 'number'}

GRADIENT_ACCUMULATION_STEPS = 1  #@param{type: 'number'}

GRADIENT_CHECKPOINTING = True #@param {type:"boolean"}
GRADIENT_CHECKPOINTING_FLAG=""
if GRADIENT_CHECKPOINTING:
  GRADIENT_CHECKPOINTING_FLAG='--gradient_checkpointing'

ENABLE_PRIOR_PRESERVATION = True #@param {type:"boolean"}
ENABLE_PRIOR_PRESERVATION_FLAG=""
if ENABLE_PRIOR_PRESERVATION:
  ENABLE_PRIOR_PRESERVATION_FLAG='--with_prior_preservation'

#@markdown Prior loss weight. Note that if you set this to 0, but enable prior preservation and provide a CLASS_DIR, you can still monitor class loss.
PRIOR_LOSS_WEIGHT = 1.0 #@param {type:"number"}

#@markdown If using prior preservation, specify a path to class images
CLASS_DIR="content/RegularizationImages" #@param{type: 'string'}
if (CLASS_DIR !="") and os.path.exists(str(CLASS_DIR)):
  CLASS_DIR=CLASS_DIR
elif (CLASS_DIR !="") and not os.path.exists(str(CLASS_DIR)):
  CLASS_DIR=input('[1;31mThe folder specified does not exist, use the colab file explorer to copy the path :')

#@markdown Prompt for prior preservation class (e.g., 'person', 'a photo of a man', 'dog'). Ignored if USE_IMAGE_CAPTIONS checked.
CLASS_PROMPT="a photo of a person" #@param {type:"string"}
#@markdown Instance prompt, {SKS} will be automatically replaced by INSTANCE_TOKEN defined above.  Ignored if USE_IMAGE_CAPTIONS checked.
INSTANCE_PROMPT="a photo of {SKS} person" #@param {type:"string"}
INSTANCE_PROMPT=INSTANCE_PROMPT.replace("{SKS}",INSTANCE_TOKEN)

#@markdown Specify the number of class images used if prior preservation is enabled. If there are not enough images in CLASS_DIR (or CLASS_DIR is empty), additional images will be generated.
MIN_NUM_CLASS_IMAGES=1500 #@param{type: 'number'}

#@markdown Batch size for generating class images
SAMPLE_BATCH_SIZE = 1 #@param{type: 'number'}

#@markdown Number of training iterations, e.g., # instance images * 100
STEPS = 10000 #@param{type: 'number'}

#@markdown Random number generator seed
SEED = 1275017 #@param{type: 'number'}

#@markdown Enable text encoder training?
TRAIN_TEXT_ENCODER = False #@param{type: 'boolean'}
TRAIN_TEXT_ENCODER_FLAG=""
if TRAIN_TEXT_ENCODER:
  TRAIN_TEXT_ENCODER_FLAG="--train_text_encoder"

#@markdown ## ADAM optimizer settings

#@markdown Use 8-bit ADAM
USE_8BIT_ADAM = True #@param {type:"boolean"}
USE_8BIT_ADAM_FLAG=""
if USE_8BIT_ADAM:
  USE_8BIT_ADAM_FLAG='--use_8bit_adam'

#@markdown The exponential decay rate for the 1st moment estimates (the beta1 parameter for the Adam optimizer).
ADAM_BETA1 = 0.9 #@param {type:"number"}

#@markdown The exponential decay rate for the 2nd moment estimates (the beta2 parameter for the Adam optimizer).
ADAM_BETA2 = 0.999 #@param {type:"number"}

#@markdown Weight decay magnitude for the Adam optimizer.
ADAM_WEIGHT_DECAY = 1e-2 #@param {type:"number"}

#@markdown Epsilon value for the Adam optimizer.
ADAM_EPSILON = 1e-08 #@param {type:"number"}

#@markdown "fp16", "bf16", or "no" according to available VRAM
MIXED_PRECISION = "fp16" #@param{type: 'string'}

#@markdown ## Learning rate parameters
LR_SCHEDULE = "cosine" #@param ["linear", "cosine", "cosine_with_restarts", "polynomial", "constant", "constant_with_warmup"]
LR = 2e-6 #@param{type: 'number'}
#@markdown If training the text encoder, a different learning rate can be applied
LR_TEXT_ENCODER = 5e-5 #@param{type: 'number'}
LR_WARMUP_STEPS = 50 #@param{type: 'number'}
#@markdown Applies only for cosine_with_restarts schedule
LR_COSINE_NUM_CYCLES = 5 #@param{type: 'number'}

# %%
#@title # (Experimental) [Data augmentation](https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0/)
#@markdown Transformations to apply to images (both instance and class).
#@markdown I find this useful to minimize the work of cropping and manually preparing images.
#@markdown This may be useful for certain applications, such as training a style, where there may not be a specific subject in each image.
#@markdown In this case, I don't crop images, and I enable random cropping, which presents to the network a randomly cropped (RESOLUTION X RESOLUTION) chunk of the original image selected for that iteration.
#@markdown AUGMENT_MIN_RESOLUTION allows you to adjust how much of the image you will crop. So if you are training for RESOLUTION=512, setting AUGMENT_MIN_RESOLUTION will give you two crops (on average) for the shortest image dimension.

#@markdown Resize image so that smallest dimension = AUGMENT_MIN_RESOLUTION (maintaining aspect ratio). Leave empty to skip.
AUGMENT_MIN_RESOLUTION = None #@param{type: 'number'}
AUGMENT_MIN_RESOLUTION_FLAG = ""
if AUGMENT_MIN_RESOLUTION is not None:
  AUGMENT_MIN_RESOLUTION = int(AUGMENT_MIN_RESOLUTION)
  AUGMENT_MIN_RESOLUTION_FLAG = f"--augment_min_resolution={AUGMENT_MIN_RESOLUTION}"

#@markdown If not enabled, defaults to center crop (which will do nothing if your images are already square at the RESOLUTION set above).
AUGMENT_RANDOM_CROP = False #@param{type: 'boolean'}
AUGMENT_CENTER_CROP_FLAG="--augment_center_crop"
if AUGMENT_RANDOM_CROP:
  AUGMENT_CENTER_CROP_FLAG=""

#@markdown Randomly flip image horizontally. Not recommended if asymmetry is important (e.g., faces).
AUGMENT_HFLIP = False #@param{type: 'boolean'}
AUGMENT_HFLIP_FLAG=""
if AUGMENT_HFLIP:
  AUGMENT_HFLIP_FLAG="--augment_hflip"

# %%
#@title # (Experimental) other training parameters

#@markdown ## [LoRA: Low-Rank Adaptation](https://arxiv.org/abs/2106.09685v2)
#@markdown Uses [clonesimo's implementation](https://github.com/cloneofsimo/lora)
USE_LORA = False #@param{type: 'boolean'}
USE_LORA_FLAG=""
if USE_LORA:
  USE_LORA_FLAG="--use_lora"

#@markdown Rank of LoRA update matrix
LORA_RANK = 4 #@param{type: 'number'}

#@markdown ## [Drop text-conditioning to improve classifier-free guidance sampling](https://arxiv.org/abs/2207.12598)

#@markdown Probability that image (applies to both instance and class images) will be selected for dropout (INSTANCE_PROMPT/CLASS_PROMPT will be replaced with UNCONDITIONAL_PROMPT)
CONDITIONING_DROPOUT_PROB = 0.0 #@param{type: 'number'}
#@markdown Defaults to an empty prompt. Unsure whether anything else would be useful.
UNCONDITIONAL_PROMPT = " " #@param{type: 'string'}

#@markdown ## Exponentially-weight moving average weights (unet only). Will not run on Tesla T4 (out of memory).
USE_EMA = False #@param{type: 'boolean'}
USE_EMA_FLAG=""
if USE_EMA:
  USE_EMA_FLAG="--use_ema"
EMA_INV_GAMMA = 1.0 #@param{type: 'number'}
EMA_POWER = 0.75 #@param{type: 'number'}
EMA_MIN_VALUE = 0 #@param{type: 'number'}
EMA_MAX_VALUE = 0.9999 #@param{type: 'number'}

# %%
#@title # Where should outputs get saved?

#@markdown Trained models (and intermediates) saved here
OUTPUT_DIR="content/models/" #@param{type: 'string'}

#@markdown Training logs saved here
LOGGING_DIR="content/logs/" #@param{type: 'string'}

if not os.path.exists(LOGGING_DIR):
  # !mkdir -p "$LOGGING_DIR"

LOG_GPU = True #@param{type: 'boolean'}
if LOG_GPU:
  LOG_GPU_FLAG="--log_gpu"
else:
  LOG_GPU_FLAG=""

# %%
#@title # Setup saving of intermediate models
#@markdown To save intermediate checkpoints, set START_SAVING_FROM_STEP < STEPS

#@markdown Number of steps between intermediate saves
SAVE_CHECKPOINT_EVERY = 500 #@param{type: 'number'}
if SAVE_CHECKPOINT_EVERY==None:
  SAVE_CHECKPOINT_EVERY = STEPS+1

START_SAVING_FROM_STEP=500 #@param{type: 'number'}
if START_SAVING_FROM_STEP==None:
  START_SAVING_FROM_STEP=STEPS

#@markdown At each intermediate checkpoint, infer this many samples using SAVE_SAMPLE_PROMPT
N_SAVE_SAMPLES=2 #@param{type: 'number'}

#@markdown {SKS} is automatically replaced by INSTANCE_TOKEN. Give multiple prompts using // as a separator
SAVE_SAMPLE_PROMPT= "a photo of {SKS} // a painting of {SKS} person by Picasso" #@param{type: 'string'}
if SAVE_SAMPLE_PROMPT=="":
  SAVE_SAMPLE_PROMPT=None
else:
  SAVE_SAMPLE_PROMPT=SAVE_SAMPLE_PROMPT.replace("{SKS}",INSTANCE_TOKEN)

#@markdown The negative prompt, on the other hand, applies to all SAVE_SAMPLE_PROMPTs
SAVE_SAMPLE_NEGATIVE_PROMPT="border" #@param{type: 'string'}

# %% [markdown]
# # Train!

# %%
#@title ## (optional) Tensorboard visualization of loss and learning rate
#@markdown Once the Tensorboard panel is launched (takes a good 10 seconds), click on the gear icon in upper right, and check Reload data. Then, after launching training in the next cell, click on TIME SERIES in upper left to see updates.
#%load_ext tensorboard
# !rm -rf content/logs
# %reload_ext tensorboard
# %tensorboard --logdir $LOGGING_DIR
# Out:
#       <iframe id="tensorboard-frame-b29f779d58953634" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b29f779d58953634");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
#@title ## Launch training
# !lsb_release -a | grep Description
# !pip freeze | grep diffusers
# !pip freeze | grep lora-diffusion
# !pip freeze | grep torchvision
# !pip freeze | grep transformers
# !pip freeze | grep xformers
# !accelerate env

# !accelerate launch \
    --mixed_precision=$MIXED_PRECISION \
    --num_machines=1 \
    --num_processes=1 \
    --dynamo_backend="no" \
    content/Dreambooth/train.py \
    $USE_LORA_FLAG \
    --lora_rank=$LORA_RANK \
    $TRAIN_TEXT_ENCODER_FLAG \
    --pretrained_model_name_or_path=$MODEL_NAME_OR_PATH \
    --pretrained_vae_name_or_path=$VAE_NAME_OR_PATH \
    --instance_data_dir="$INSTANCE_DIR" \
    --class_data_dir="$CLASS_DIR" \
    --output_dir="$OUTPUT_DIR" \
    --logging_dir="$LOGGING_DIR" \
    $LOG_GPU_FLAG \
    $ENABLE_PRIOR_PRESERVATION_FLAG \
    --prior_loss_weight=$PRIOR_LOSS_WEIGHT \
    --instance_prompt="$INSTANCE_PROMPT" \
    --class_prompt="$CLASS_PROMPT" \
    $USE_IMAGE_CAPTIONS_FLAG \
    --conditioning_dropout_prob=$CONDITIONING_DROPOUT_PROB \
    --unconditional_prompt="$UNCONDITIONAL_PROMPT" \
    --seed=$SEED \
    --resolution=$RESOLUTION \
    --train_batch_size=$TRAIN_BATCH_SIZE \
    --gradient_accumulation_steps=$GRADIENT_ACCUMULATION_STEPS \
    $GRADIENT_CHECKPOINTING_FLAG \
    --mixed_precision=$MIXED_PRECISION \
    $USE_8BIT_ADAM_FLAG \
    --adam_beta1=$ADAM_BETA1 \
    --adam_beta2=$ADAM_BETA2 \
    --adam_weight_decay=$ADAM_WEIGHT_DECAY \
    --adam_epsilon=$ADAM_EPSILON \
    --learning_rate=$LR \
    --learning_rate_text=$LR_TEXT_ENCODER \
    --lr_scheduler=$LR_SCHEDULE \
    --lr_warmup_steps=$LR_WARMUP_STEPS \
    --lr_cosine_num_cycles=$LR_COSINE_NUM_CYCLES \
    $USE_EMA_FLAG \
    --ema_inv_gamma=$EMA_INV_GAMMA \
    --ema_power=$EMA_POWER \
    --ema_min_value=$EMA_MIN_VALUE \
    --ema_max_value=$EMA_MAX_VALUE \
    --max_train_steps=$STEPS \
    --num_class_images=$MIN_NUM_CLASS_IMAGES \
    --sample_batch_size=$SAMPLE_BATCH_SIZE \
    --save_min_steps=$START_SAVING_FROM_STEP \
    --save_interval=$SAVE_CHECKPOINT_EVERY \
    --n_save_sample=$N_SAVE_SAMPLES \
    --save_sample_prompt="$SAVE_SAMPLE_PROMPT" \
    --save_sample_negative_prompt="$SAVE_SAMPLE_NEGATIVE_PROMPT" \
    $AUGMENT_MIN_RESOLUTION_FLAG \
    $AUGMENT_CENTER_CROP_FLAG \
    $AUGMENT_HFLIP_FLAG
# Out:
# No LSB modules are available.
# Description:	Ubuntu 18.04.5 LTS
# WARNING: Ignoring invalid distribution -ransformers (/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages)
# diffusers==0.11.1
# WARNING: Ignoring invalid distribution -ransformers (/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages)
# lora-diffusion @ file:///home/nas4_user/saemeechoi/course/AdvancedDeepLearning/notebooks/content/lora
# WARNING: Ignoring invalid distribution -ransformers (/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages)
# torchvision==0.15.2
# WARNING: Ignoring invalid distribution -ransformers (/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages)
# transformers==4.25.1
# WARNING: Ignoring invalid distribution -ransformers (/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages)
# xformers==0.0.23
#
# Copy-and-paste the text below in your GitHub issue
#
# - `Accelerate` version: 0.15.0
# - Platform: Linux-4.15.0-175-generic-x86_64-with-glibc2.27
# - Python version: 3.9.18
# - Numpy version: 1.26.2
# - PyTorch version (GPU?): 2.0.1 (True)
# - `Accelerate` default config:
# 	Not found
# WARNING[XFORMERS]: xFormers can't load C++/CUDA extensions. xFormers was built for:
#     PyTorch 2.1.1+cu121 with CUDA 1201 (you have 2.0.1)
#     Python  3.9.18 (you have 3.9.18)
#   Please reinstall xformers (see https://github.com/facebookresearch/xformers#installing-xformers)
#   Memory-efficient attention, SwiGLU, sparse and more won't be available.
#   Set XFORMERS_MORE_DETAILS=1 for more details
# diffusion_pytorch_model.safetensors: 100%|███| 335M/335M [00:06<00:00, 54.6MB/s]
# vae/config.json: 100%|██████████████████████████| 547/547 [00:00<00:00, 103kB/s]
# model_index.json: 100%|████████████████████████| 541/541 [00:00<00:00, 90.5kB/s]
# safety_checker/pytorch_model.fp16.safetensors not found
# Fetching 29 files:   0%|                                 | 0/29 [00:00<?, ?it/s]
# model.safetensors:   0%|                            | 0.00/1.22G [00:00<?, ?B/s]
#
# pytorch_model.bin:   0%|                            | 0.00/1.22G [00:00<?, ?B/s]
#
#
# pytorch_model.fp16.bin:   0%|                        | 0.00/608M [00:00<?, ?B/s]
#
#
#
# (…)ature_extractor/preprocessor_config.json: 100%|█| 342/342 [00:00<00:00, 61.9k
# Fetching 29 files:   3%|▊                        | 1/29 [00:00<00:19,  1.45it/s]
#
#
#
# safety_checker/config.json: 100%|███████████| 4.72k/4.72k [00:00<00:00, 706kB/s]
#
#
#
#
# scheduler/scheduler_config.json: 100%|█████████| 308/308 [00:00<00:00, 55.8kB/s]
#
# model.safetensors:   1%|▏                  | 10.5M/1.22G [00:00<00:38, 30.9MB/s]
#
#
#
# model.safetensors:   0%|                             | 0.00/492M [00:00<?, ?B/s]
#
#
#
#
# text_encoder/config.json: 100%|█████████████████| 617/617 [00:00<00:00, 116kB/s]
#
#
#
#
#
# pytorch_model.bin:   0%|                             | 0.00/492M [00:00<?, ?B/s]
# model.safetensors:   2%|▎                  | 21.0M/1.22G [00:00<00:43, 27.4MB/s]
#
#
#
#
#
# model.fp16.safetensors:   0%|                        | 0.00/608M [00:00<?, ?B/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:   0%|                        | 0.00/246M [00:00<?, ?B/s]
#
#
# pytorch_model.fp16.bin:   2%|▎              | 10.5M/608M [00:01<01:04, 9.21MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:   0%|                        | 0.00/246M [00:00<?, ?B/s]
# model.safetensors:   3%|▍                  | 31.5M/1.22G [00:01<00:54, 21.7MB/s]
#
#
#
# model.safetensors:   2%|▍                   | 10.5M/492M [00:01<01:05, 7.38MB/s]
#
# pytorch_model.bin:   1%|▏                  | 10.5M/1.22G [00:01<03:36, 5.57MB/s]
# model.safetensors:   3%|▋                  | 41.9M/1.22G [00:02<01:10, 16.6MB/s]
#
#
#
#
# pytorch_model.bin:   2%|▍                   | 10.5M/492M [00:01<01:21, 5.88MB/s]
#
#
# pytorch_model.fp16.bin:   3%|▌              | 21.0M/608M [00:02<01:24, 6.91MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:   4%|▋              | 10.5M/246M [00:01<00:37, 6.21MB/s]
# model.safetensors:   4%|▊                  | 52.4M/1.22G [00:03<01:27, 13.3MB/s]
#
#
#
# model.safetensors:   4%|▊                   | 21.0M/492M [00:02<01:02, 7.48MB/s]
#
# pytorch_model.bin:   2%|▎                  | 21.0M/1.22G [00:04<03:58, 5.00MB/s]
# model.safetensors:   5%|▉                  | 62.9M/1.22G [00:04<01:34, 12.2MB/s]
#
#
#
#
#
# model.fp16.safetensors:   2%|▎              | 10.5M/608M [00:03<03:17, 3.02MB/s]
#
#
#
#
# pytorch_model.bin:   4%|▊                   | 21.0M/492M [00:03<01:22, 5.74MB/s]
#
#
# pytorch_model.fp16.bin:   5%|▊              | 31.5M/608M [00:04<01:21, 7.11MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:   9%|█▎             | 21.0M/246M [00:03<00:35, 6.43MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:   4%|▋              | 10.5M/246M [00:03<01:24, 2.79MB/s]
#
#
#
# model.safetensors:   6%|█▎                  | 31.5M/492M [00:04<01:14, 6.21MB/s]
# model.safetensors:   6%|█▏                 | 73.4M/1.22G [00:05<01:40, 11.3MB/s]
#
#
# pytorch_model.fp16.bin:   7%|█              | 41.9M/608M [00:05<01:11, 7.96MB/s]
#
# pytorch_model.bin:   3%|▍                  | 31.5M/1.22G [00:05<03:37, 5.45MB/s]
# model.safetensors:   7%|█▎                 | 83.9M/1.22G [00:06<01:47, 10.5MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  13%|█▉             | 31.5M/246M [00:05<00:35, 5.97MB/s]
#
#
# pytorch_model.fp16.bin:   9%|█▎             | 52.4M/608M [00:06<01:04, 8.66MB/s]
#
#
#
#
# pytorch_model.bin:   6%|█▎                  | 31.5M/492M [00:06<01:31, 5.04MB/s]
#
#
#
# model.safetensors:   9%|█▋                  | 41.9M/492M [00:06<01:12, 6.19MB/s]
#
#
#
#
#
# model.fp16.safetensors:   3%|▌              | 21.0M/608M [00:06<03:03, 3.19MB/s]
#
#
# pytorch_model.fp16.bin:  10%|█▌             | 62.9M/608M [00:07<01:01, 8.94MB/s]
#
# pytorch_model.bin:   3%|▋                  | 41.9M/1.22G [00:07<03:34, 5.47MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:   9%|█▎             | 21.0M/246M [00:06<01:12, 3.12MB/s]
# model.safetensors:   8%|█▍                 | 94.4M/1.22G [00:08<02:03, 9.06MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  17%|██▌            | 41.9M/246M [00:06<00:33, 6.01MB/s]
#
#
#
#
# pytorch_model.bin:   9%|█▋                  | 41.9M/492M [00:07<01:21, 5.53MB/s]
#
#
# pytorch_model.fp16.bin:  12%|█▊             | 73.4M/608M [00:08<00:58, 9.07MB/s]
#
#
#
# model.safetensors:  11%|██▏                 | 52.4M/492M [00:08<01:15, 5.85MB/s]
#
#
#
#
# pytorch_model.bin:  11%|██▏                 | 52.4M/492M [00:08<01:04, 6.77MB/s]
# model.safetensors:   9%|█▋                  | 105M/1.22G [00:09<02:21, 7.86MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  21%|███▏           | 52.4M/246M [00:08<00:30, 6.25MB/s]
#
#
# pytorch_model.fp16.bin:  14%|██             | 83.9M/608M [00:09<00:59, 8.84MB/s]
#
# pytorch_model.bin:   4%|▊                  | 52.4M/1.22G [00:09<03:44, 5.19MB/s]
#
#
#
#
# pytorch_model.bin:  13%|██▌                 | 62.9M/492M [00:09<00:54, 7.86MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  13%|█▉             | 31.5M/246M [00:09<01:00, 3.56MB/s]
#
#
#
#
# pytorch_model.bin:  15%|██▉                 | 73.4M/492M [00:10<00:45, 9.28MB/s]
#
#
#
# model.safetensors:  13%|██▌                 | 62.9M/492M [00:10<01:20, 5.32MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  26%|███▊           | 62.9M/246M [00:10<00:29, 6.13MB/s]
#
#
# pytorch_model.fp16.bin:  16%|██▎            | 94.4M/608M [00:11<01:04, 7.92MB/s]
#
#
#
#
#
# model.fp16.safetensors:   5%|▊              | 31.5M/608M [00:10<03:20, 2.87MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  17%|██▌            | 41.9M/246M [00:10<00:45, 4.47MB/s]
# model.safetensors:   9%|█▉                  | 115M/1.22G [00:11<02:45, 6.66MB/s]
#
#
#
#
# pytorch_model.bin:  17%|███▍                | 83.9M/492M [00:11<00:42, 9.57MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  21%|███▏           | 52.4M/246M [00:11<00:35, 5.52MB/s]
#
#
# pytorch_model.fp16.bin:  17%|██▊             | 105M/608M [00:13<01:05, 7.64MB/s]
#
#
#
# model.safetensors:  15%|██▉                 | 73.4M/492M [00:12<01:17, 5.41MB/s]
#
#
#
#
# pytorch_model.bin:  19%|███▊                | 94.4M/492M [00:12<00:44, 8.97MB/s]
#
# pytorch_model.bin:   5%|▉                  | 62.9M/1.22G [00:13<04:42, 4.08MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  30%|████▍          | 73.4M/246M [00:12<00:30, 5.59MB/s]
#
#
#
#
#
# model.fp16.safetensors:   7%|█              | 41.9M/608M [00:13<02:48, 3.36MB/s]
# model.safetensors:  10%|██                  | 126M/1.22G [00:13<03:01, 6.00MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  26%|███▊           | 62.9M/246M [00:12<00:28, 6.35MB/s]
#
#
# pytorch_model.fp16.bin:  19%|███             | 115M/608M [00:14<01:06, 7.43MB/s]
#
#
#
#
# pytorch_model.bin:  21%|████▍                | 105M/492M [00:14<00:48, 8.01MB/s]
#
#
#
# model.safetensors:  17%|███▍                | 83.9M/492M [00:14<01:13, 5.58MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  30%|████▍          | 73.4M/246M [00:14<00:25, 6.69MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  34%|█████          | 83.9M/246M [00:14<00:29, 5.46MB/s]
# model.safetensors:  11%|██▏                 | 136M/1.22G [00:15<03:05, 5.82MB/s]
#
#
# pytorch_model.fp16.bin:  21%|███▎            | 126M/608M [00:15<01:04, 7.44MB/s]
#
#
#
# model.safetensors:  19%|███▊                | 94.4M/492M [00:15<01:02, 6.37MB/s]
#
# pytorch_model.bin:   6%|█▏                 | 73.4M/1.22G [00:16<04:37, 4.11MB/s]
#
#
#
#
#
# model.fp16.safetensors:   9%|█▎             | 52.4M/608M [00:15<02:36, 3.54MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  34%|█████          | 83.9M/246M [00:16<00:24, 6.63MB/s]
#
#
#
# model.safetensors:  21%|████▍                | 105M/492M [00:16<00:53, 7.30MB/s]
#
#
#
#
# pytorch_model.bin:  23%|████▉                | 115M/492M [00:16<00:57, 6.52MB/s]
#
#
# pytorch_model.fp16.bin:  22%|███▌            | 136M/608M [00:17<01:05, 7.18MB/s]
#
# pytorch_model.bin:   7%|█▎                 | 83.9M/1.22G [00:17<04:04, 4.63MB/s]
#
#
#
# model.safetensors:  23%|████▉                | 115M/492M [00:17<00:47, 8.02MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  38%|█████▊         | 94.4M/246M [00:16<00:29, 5.17MB/s]
# model.safetensors:  12%|██▍                 | 147M/1.22G [00:18<03:14, 5.48MB/s]
#
#
# pytorch_model.fp16.bin:  24%|███▊            | 147M/608M [00:18<01:00, 7.60MB/s]
#
#
#
# model.safetensors:  26%|█████▎               | 126M/492M [00:18<00:41, 8.74MB/s]
#
#
#
#
# pytorch_model.bin:  26%|█████▎               | 126M/492M [00:18<00:58, 6.24MB/s]
#
#
#
#
#
# model.fp16.safetensors:  10%|█▌             | 62.9M/608M [00:18<02:28, 3.68MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  38%|█████▊         | 94.4M/246M [00:18<00:25, 5.87MB/s]
#
# pytorch_model.bin:   8%|█▍                 | 94.4M/1.22G [00:19<03:57, 4.73MB/s]
# model.safetensors:  13%|██▌                 | 157M/1.22G [00:20<03:15, 5.42MB/s]
#
#
#
# model.safetensors:  28%|█████▊               | 136M/492M [00:19<00:40, 8.89MB/s]
#
#
# pytorch_model.fp16.bin:  26%|████▏           | 157M/608M [00:20<01:01, 7.33MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  43%|██████▊         | 105M/246M [00:19<00:23, 6.12MB/s]
#
#
#
#
#
# model.fp16.safetensors:  12%|█▊             | 73.4M/608M [00:20<02:05, 4.26MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  43%|██████▊         | 105M/246M [00:19<00:30, 4.59MB/s]
#
#
#
# model.safetensors:  30%|██████▎              | 147M/492M [00:20<00:35, 9.60MB/s]
#
#
#
#
# pytorch_model.bin:  28%|█████▊               | 136M/492M [00:20<01:03, 5.61MB/s]
#
# pytorch_model.bin:   9%|█▋                  | 105M/1.22G [00:21<03:36, 5.12MB/s]
#
#
# pytorch_model.fp16.bin:  28%|████▍           | 168M/608M [00:21<01:02, 7.03MB/s]
#
#
#
# model.safetensors:  32%|██████▋              | 157M/492M [00:21<00:35, 9.41MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  47%|███████▍        | 115M/246M [00:21<00:20, 6.37MB/s]
#
#
#
#
#
# model.fp16.safetensors:  14%|██             | 83.9M/608M [00:21<01:52, 4.66MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  47%|███████▍        | 115M/246M [00:21<00:27, 4.73MB/s]
# model.safetensors:  14%|██▊                 | 168M/1.22G [00:23<03:45, 4.64MB/s]
#
#
# pytorch_model.fp16.bin:  29%|████▋           | 178M/608M [00:23<00:59, 7.27MB/s]
#
#
#
# model.safetensors:  34%|███████▏             | 168M/492M [00:23<00:36, 8.92MB/s]
#
# pytorch_model.bin:   9%|█▉                  | 115M/1.22G [00:23<03:33, 5.15MB/s]
#
#
#
#
#
# model.fp16.safetensors:  16%|██▎            | 94.4M/608M [00:23<01:41, 5.05MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  51%|████████▏       | 126M/246M [00:23<00:20, 5.79MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  51%|████████▏       | 126M/246M [00:23<00:22, 5.23MB/s]
# model.safetensors:  15%|██▉                 | 178M/1.22G [00:24<03:18, 5.22MB/s]
#
#
#
#
# pytorch_model.bin:  30%|██████▎              | 147M/492M [00:23<01:15, 4.59MB/s]
#
#
# pytorch_model.fp16.bin:  31%|████▉           | 189M/608M [00:24<00:57, 7.36MB/s]
#
#
# pytorch_model.fp16.bin:  33%|█████▏          | 199M/608M [00:25<00:45, 9.07MB/s]
#
#
#
# model.safetensors:  36%|███████▌             | 178M/492M [00:24<00:40, 7.84MB/s]
#
#
# pytorch_model.fp16.bin:  34%|█████▌          | 210M/608M [00:25<00:37, 10.7MB/s]
#
# pytorch_model.bin:  10%|██                  | 126M/1.22G [00:26<03:47, 4.80MB/s]
#
#
#
#
#
# model.fp16.safetensors:  17%|██▊             | 105M/608M [00:25<01:34, 5.30MB/s]
# model.safetensors:  16%|███                 | 189M/1.22G [00:26<03:14, 5.27MB/s]
#
#
# pytorch_model.fp16.bin:  36%|█████▊          | 220M/608M [00:26<00:33, 11.7MB/s]
#
#
#
# model.safetensors:  38%|████████             | 189M/492M [00:26<00:41, 7.28MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  55%|████████▊       | 136M/246M [00:26<00:21, 5.07MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  55%|████████▊       | 136M/246M [00:25<00:23, 4.75MB/s]
#
#
# pytorch_model.fp16.bin:  38%|██████          | 231M/608M [00:27<00:31, 12.0MB/s]
#
#
# pytorch_model.fp16.bin:  40%|██████▎         | 241M/608M [00:28<00:31, 11.7MB/s]
#
# pytorch_model.bin:  11%|██▏                 | 136M/1.22G [00:28<03:43, 4.83MB/s]
# model.safetensors:  16%|███▎                | 199M/1.22G [00:28<03:07, 5.41MB/s]
#
#
#
#
#
# model.fp16.safetensors:  19%|███             | 115M/608M [00:27<01:36, 5.10MB/s]
#
#
#
# model.safetensors:  40%|████████▍            | 199M/492M [00:28<00:42, 6.96MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  60%|█████████▌      | 147M/246M [00:27<00:18, 5.51MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  60%|█████████▌      | 147M/246M [00:27<00:19, 5.16MB/s]
#
#
# pytorch_model.fp16.bin:  41%|██████▌         | 252M/608M [00:29<00:32, 11.0MB/s]
#
#
#
#
# pytorch_model.bin:  32%|██████▋              | 157M/492M [00:29<01:40, 3.33MB/s]
#
# pytorch_model.bin:  12%|██▍                 | 147M/1.22G [00:29<03:24, 5.22MB/s]
# model.safetensors:  17%|███▍                | 210M/1.22G [00:30<03:04, 5.47MB/s]
#
#
#
# model.safetensors:  43%|████████▉            | 210M/492M [00:29<00:41, 6.76MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  64%|██████████▏     | 157M/246M [00:29<00:16, 5.51MB/s]
#
#
# pytorch_model.fp16.bin:  43%|██████▉         | 262M/608M [00:30<00:33, 10.4MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  64%|██████████▏     | 157M/246M [00:29<00:16, 5.46MB/s]
#
# pytorch_model.bin:  13%|██▌                 | 157M/1.22G [00:31<03:05, 5.69MB/s]
#
#
#
#
#
# model.fp16.safetensors:  21%|███▎            | 126M/608M [00:30<01:48, 4.44MB/s]
#
#
# pytorch_model.fp16.bin:  45%|███████▏        | 273M/608M [00:31<00:35, 9.57MB/s]
#
#
#
# model.safetensors:  45%|█████████▍           | 220M/492M [00:31<00:41, 6.64MB/s]
# model.safetensors:  18%|███▌                | 220M/1.22G [00:31<02:59, 5.54MB/s]
#
#
#
#
# pytorch_model.bin:  34%|███████▏             | 168M/492M [00:31<01:29, 3.61MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  68%|██████████▉     | 168M/246M [00:30<00:14, 5.54MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  68%|██████████▉     | 168M/246M [00:31<00:13, 5.66MB/s]
#
# pytorch_model.bin:  14%|██▊                 | 168M/1.22G [00:32<02:51, 6.11MB/s]
#
#
# pytorch_model.fp16.bin:  47%|███████▍        | 283M/608M [00:33<00:37, 8.67MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  72%|███████████▌    | 178M/246M [00:32<00:10, 6.42MB/s]
#
#
#
#
#
# model.fp16.safetensors:  22%|███▌            | 136M/608M [00:32<01:42, 4.60MB/s]
#
#
#
# model.safetensors:  47%|█████████▊           | 231M/492M [00:33<00:42, 6.15MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  77%|████████████▎   | 189M/246M [00:33<00:07, 7.48MB/s]
#
#
#
#
# pytorch_model.bin:  36%|███████▌             | 178M/492M [00:33<01:21, 3.85MB/s]
#
#
# pytorch_model.fp16.bin:  48%|███████▋        | 294M/608M [00:34<00:36, 8.67MB/s]
#
# pytorch_model.bin:  15%|██▉                 | 178M/1.22G [00:34<02:49, 6.11MB/s]
# model.safetensors:  19%|███▊                | 231M/1.22G [00:34<03:16, 5.02MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  72%|███████████▌    | 178M/246M [00:33<00:14, 4.79MB/s]
#
#
#
#
#
# model.fp16.safetensors:  24%|███▊            | 147M/608M [00:34<01:32, 4.97MB/s]
# model.safetensors:  20%|███▉                | 241M/1.22G [00:35<02:45, 5.89MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  81%|████████████▉   | 199M/246M [00:34<00:06, 7.16MB/s]
#
#
# pytorch_model.fp16.bin:  50%|████████        | 304M/608M [00:36<00:39, 7.75MB/s]
# model.safetensors:  21%|████▏               | 252M/1.22G [00:36<02:17, 7.01MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  77%|████████████▎   | 189M/246M [00:35<00:10, 5.47MB/s]
#
#
#
# model.safetensors:  49%|██████████▎          | 241M/492M [00:36<00:48, 5.22MB/s]
#
# pytorch_model.bin:  16%|███                 | 189M/1.22G [00:36<03:10, 5.39MB/s]
#
#
#
#
#
# model.fp16.safetensors:  26%|████▏           | 157M/608M [00:36<01:27, 5.14MB/s]
#
#
#
#
# pytorch_model.bin:  38%|████████             | 189M/492M [00:36<01:21, 3.73MB/s]
#
#
# pytorch_model.fp16.bin:  52%|████████▎       | 315M/608M [00:37<00:37, 7.83MB/s]
# model.safetensors:  22%|████▎               | 262M/1.22G [00:37<02:07, 7.46MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  81%|████████████▉   | 199M/246M [00:36<00:07, 5.89MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  85%|█████████████▋  | 210M/246M [00:37<00:06, 6.06MB/s]
#
#
#
#
#
# model.fp16.safetensors:  28%|████▍           | 168M/608M [00:37<01:17, 5.67MB/s]
#
#
# pytorch_model.fp16.bin:  53%|████████▌       | 325M/608M [00:38<00:36, 7.72MB/s]
#
# pytorch_model.bin:  16%|███▎                | 199M/1.22G [00:38<03:07, 5.43MB/s]
# model.safetensors:  22%|████▍               | 273M/1.22G [00:38<02:04, 7.59MB/s]
#
#
#
#
# pytorch_model.bin:  40%|████████▍            | 199M/492M [00:38<01:11, 4.08MB/s]
#
# pytorch_model.bin:  17%|███▍                | 210M/1.22G [00:39<02:41, 6.23MB/s]
#
#
# pytorch_model.fp16.bin:  55%|████████▊       | 336M/608M [00:40<00:34, 7.93MB/s]
# model.safetensors:  23%|████▋               | 283M/1.22G [00:40<01:59, 7.79MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  89%|██████████████▎ | 220M/246M [00:39<00:04, 5.83MB/s]
#
#
#
#
#
# model.fp16.safetensors:  29%|████▋           | 178M/608M [00:39<01:14, 5.74MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  85%|█████████████▋  | 210M/246M [00:39<00:07, 5.19MB/s]
#
#
#
# model.safetensors:  51%|██████████▋          | 252M/492M [00:40<01:00, 3.95MB/s]
#
# pytorch_model.bin:  18%|███▌                | 220M/1.22G [00:41<02:27, 6.74MB/s]
# model.safetensors:  24%|████▊               | 294M/1.22G [00:41<01:53, 8.12MB/s]
#
#
#
#
# pytorch_model.bin:  43%|████████▉            | 210M/492M [00:40<01:06, 4.28MB/s]
#
#
# pytorch_model.fp16.bin:  57%|█████████       | 346M/608M [00:41<00:35, 7.48MB/s]
#
#
#
#
#
# model.fp16.safetensors:  31%|████▉           | 189M/608M [00:41<01:11, 5.84MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  94%|██████████████▉ | 231M/246M [00:41<00:02, 5.80MB/s]
# model.safetensors:  25%|█████               | 304M/1.22G [00:42<01:45, 8.65MB/s]
#
# pytorch_model.bin:  19%|███▊                | 231M/1.22G [00:42<02:21, 6.96MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  89%|██████████████▎ | 220M/246M [00:41<00:05, 4.87MB/s]
#
#
#
#
# pytorch_model.bin:  45%|█████████▍           | 220M/492M [00:42<00:55, 4.92MB/s]
# model.safetensors:  26%|█████▏              | 315M/1.22G [00:43<01:41, 8.89MB/s]
#
#
# pytorch_model.fp16.bin:  59%|█████████▍      | 357M/608M [00:43<00:38, 6.60MB/s]
#
#
#
#
#
# model.fp16.safetensors:  33%|█████▏          | 199M/608M [00:43<01:11, 5.71MB/s]
#
#
#
#
# pytorch_model.bin:  47%|█████████▊           | 231M/492M [00:43<00:45, 5.78MB/s]
#
# pytorch_model.bin:  20%|███▉                | 241M/1.22G [00:43<02:17, 7.07MB/s]
# model.safetensors:  27%|█████▎              | 325M/1.22G [00:44<01:34, 9.47MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin:  98%|███████████████▋| 241M/246M [00:44<00:01, 4.83MB/s]
#
#
#
#
# pytorch_model.bin:  49%|██████████▎          | 241M/492M [00:44<00:39, 6.42MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  94%|██████████████▉ | 231M/246M [00:43<00:03, 4.76MB/s]
# model.safetensors:  28%|█████▌              | 336M/1.22G [00:45<01:30, 9.72MB/s]
#
#
#
#
#
# model.fp16.safetensors:  34%|█████▌          | 210M/608M [00:44<01:06, 6.00MB/s]
#
#
#
#
# pytorch_model.bin:  51%|██████████▋          | 252M/492M [00:45<00:30, 7.93MB/s]
#
#
#
#
#
#
# pytorch_model.fp16.bin: 100%|████████████████| 246M/246M [00:45<00:00, 5.46MB/s]
#
#
# pytorch_model.bin:  21%|████▏               | 252M/1.22G [00:46<02:32, 6.32MB/s]
# model.safetensors:  28%|█████▋              | 346M/1.22G [00:46<01:26, 10.1MB/s]
#
#
#
#
# pytorch_model.bin:  53%|███████████▏         | 262M/492M [00:45<00:25, 9.02MB/s]
#
#
#
#
#
#
# tokenizer/merges.txt:   0%|                          | 0.00/525k [00:00<?, ?B/s]
#
#
#
#
#
#
#
# model.fp16.safetensors:  98%|███████████████▋| 241M/246M [00:45<00:00, 5.06MB/s]
# model.safetensors:  29%|█████▊              | 357M/1.22G [00:47<01:19, 10.8MB/s]
#
#
#
#
#
# model.fp16.safetensors:  36%|█████▊          | 220M/608M [00:46<01:05, 5.95MB/s]
#
#
# pytorch_model.fp16.bin:  60%|█████████▋      | 367M/608M [00:47<00:51, 4.68MB/s]
#
#
#
#
#
#
# tokenizer/merges.txt: 100%|███████████████████| 525k/525k [00:00<00:00, 779kB/s]
#
#
#
#
#
# pytorch_model.bin:  55%|███████████▋         | 273M/492M [00:46<00:23, 9.50MB/s]
#
#
#
#
#
#
#
# model.fp16.safetensors: 100%|████████████████| 246M/246M [00:46<00:00, 5.31MB/s]
#
#
# pytorch_model.bin:  22%|████▎               | 262M/1.22G [00:47<02:34, 6.19MB/s]
#
#
#
#
#
#
# tokenizer/special_tokens_map.json: 100%|████████| 472/472 [00:00<00:00, 411kB/s]
#
#
#
#
#
#
#
# tokenizer/tokenizer_config.json: 100%|██████████| 806/806 [00:00<00:00, 172kB/s]
#
#
#
#
# model.safetensors:  53%|███████████▏         | 262M/492M [00:47<01:29, 2.56MB/s]
# model.safetensors:  30%|██████              | 367M/1.22G [00:48<01:18, 10.8MB/s]
#
#
#
#
#
#
# tokenizer/vocab.json:   0%|                         | 0.00/1.06M [00:00<?, ?B/s]
#
#
#
#
#
# model.fp16.safetensors:  38%|██████          | 231M/608M [00:47<00:57, 6.56MB/s]
#
# pytorch_model.bin:  22%|████▍               | 273M/1.22G [00:48<02:11, 7.20MB/s]
#
#
#
#
#
#
#
# unet/config.json: 100%|█████████████████████████| 743/743 [00:00<00:00, 516kB/s]
#
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   0%|                  | 0.00/3.44G [00:00<?, ?B/s]
#
#
#
#
#
# model.fp16.safetensors:  40%|██████▎         | 241M/608M [00:48<00:46, 7.94MB/s]
# model.safetensors:  31%|██████▏             | 377M/1.22G [00:49<01:18, 10.7MB/s]
#
#
#
#
#
#
# tokenizer/vocab.json: 100%|████████████████| 1.06M/1.06M [00:00<00:00, 1.13MB/s]
#
#
# pytorch_model.bin:  23%|████▋               | 283M/1.22G [00:49<01:52, 8.26MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:   0%|             | 0.00/1.72G [00:00<?, ?B/s]
#
#
#
#
#
# model.fp16.safetensors:  41%|██████▌         | 252M/608M [00:49<00:40, 8.79MB/s]
#
#
# pytorch_model.fp16.bin:  62%|█████████▉      | 377M/608M [00:50<00:53, 4.34MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   0%|         | 10.5M/3.44G [00:01<06:26, 8.86MB/s]
# model.safetensors:  32%|██████▍             | 388M/1.22G [00:50<01:25, 9.64MB/s]
#
# pytorch_model.bin:  24%|████▊               | 294M/1.22G [00:50<01:45, 8.77MB/s]
#
#
#
#
#
# model.fp16.safetensors:  43%|██████▉         | 262M/608M [00:50<00:38, 8.90MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   1%|         | 21.0M/3.44G [00:02<05:54, 9.64MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:   1%|    | 10.5M/1.72G [00:02<05:43, 4.98MB/s]
# model.safetensors:  33%|██████▌             | 398M/1.22G [00:51<01:28, 9.22MB/s]
#
# pytorch_model.bin:  25%|█████               | 304M/1.22G [00:52<01:50, 8.25MB/s]
#
#
# pytorch_model.fp16.bin:  64%|██████████▏     | 388M/608M [00:52<00:48, 4.55MB/s]
#
#
#
# model.safetensors:  55%|███████████▋         | 273M/492M [00:51<01:26, 2.53MB/s]
#
#
#
#
#
# model.fp16.safetensors:  45%|███████▏        | 273M/608M [00:51<00:38, 8.72MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   1%|         | 31.5M/3.44G [00:03<06:44, 8.41MB/s]
# model.safetensors:  34%|██████▋             | 409M/1.22G [00:52<01:27, 9.26MB/s]
#
# pytorch_model.bin:  26%|█████▏              | 315M/1.22G [00:53<01:55, 7.82MB/s]
#
#
#
#
#
# model.fp16.safetensors:  47%|███████▍        | 283M/608M [00:52<00:37, 8.68MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   1%|         | 41.9M/3.44G [00:04<06:27, 8.77MB/s]
# model.safetensors:  34%|██████▉             | 419M/1.22G [00:53<01:24, 9.46MB/s]
#
#
# pytorch_model.fp16.bin:  66%|██████████▍     | 398M/608M [00:54<00:45, 4.65MB/s]
#
#
#
# model.safetensors:  58%|████████████         | 283M/492M [00:53<01:09, 2.99MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:   1%|    | 21.0M/1.72G [00:04<06:42, 4.22MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   2%|▏        | 52.4M/3.44G [00:05<06:09, 9.17MB/s]
#
#
#
#
#
# model.fp16.safetensors:  48%|███████▋        | 294M/608M [00:54<00:36, 8.55MB/s]
# model.safetensors:  35%|███████             | 430M/1.22G [00:55<01:22, 9.50MB/s]
#
# pytorch_model.bin:  27%|█████▎              | 325M/1.22G [00:55<02:08, 6.92MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   2%|▏        | 62.9M/3.44G [00:06<05:44, 9.78MB/s]
#
#
#
#
#
# model.fp16.safetensors:  50%|████████        | 304M/608M [00:55<00:33, 9.00MB/s]
#
#
#
# model.safetensors:  60%|████████████▌        | 294M/492M [00:55<00:56, 3.50MB/s]
# model.safetensors:  36%|███████▏            | 440M/1.22G [00:56<01:26, 8.98MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:   2%|    | 31.5M/1.72G [00:07<06:37, 4.25MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   2%|▏        | 73.4M/3.44G [00:07<05:47, 9.69MB/s]
#
#
# pytorch_model.fp16.bin:  67%|██████████▊     | 409M/608M [00:56<00:44, 4.49MB/s]
#
#
#
#
#
# model.fp16.safetensors:  52%|████████▎       | 315M/608M [00:56<00:32, 8.98MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:   2%|    | 41.9M/1.72G [00:07<04:30, 6.19MB/s]
#
#
#
# model.safetensors:  62%|████████████▉        | 304M/492M [00:57<00:46, 4.05MB/s]Error while downloading from https://cdn-lfs.huggingface.co/repos/6b/20/6b201da5f0f5c60524535ebb7deac2eef68605655d3bbacfee9cce0087f3b3f5/770a47a9ffdcfda0b05506a7888ed714d06131d60267e6cf52765d61cf59fd67?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27pytorch_model.bin%3B+filename%3D%22pytorch_model.bin%22%3B&response-content-type=application%2Foctet-stream&Expires=1702559997&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=pQvfO6yfdGteGgDWJVz%7Eb9J4rxG2Wcii-82hgDpOSBO6%7EX529MEcS1-MSfUIcS9VKQssly-ROOPSlvIXhzyUtWIQJdmeCIAdOkr9QO%7ExofVnFqJzX0VTyc%7EB-rHIkmV-CI5yoXgR0g8frVsOFf8Lad%7EN0rpio6Em9twa%7EkL--u8O%7EAZW5QtBYtPPNizTPm0dZ2jQ3q6r1M%7E7UkEOf875nrLj%7ES7aeudd5%7E91bq6iGpx4a4rjZcX-YRTcOBz0It7Rn5UkdyOWvcYloliw8h9-lub28iawENFYILZ6kByp42StdmBLtsxO9Yd6Lr4JpD7ufGOuYNXLhIcv-z9FBp1Cnw__&Key-Pair-Id=KVTP0A1DKRTAX: HTTPSConnectionPool(host='cdn-lfs.huggingface.co', port=443): Read timed out.
# Trying to resume download...
#
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:   3%|    | 52.4M/1.72G [00:08<03:29, 7.95MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   2%|▏        | 83.9M/3.44G [00:09<06:32, 8.55MB/s]
#
#
#
#
#
# model.fp16.safetensors:  53%|████████▌       | 325M/608M [00:57<00:34, 8.12MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:   4%|▏   | 62.9M/1.72G [00:09<02:53, 9.53MB/s]
# model.safetensors:  37%|███████▍            | 451M/1.22G [00:58<01:53, 6.75MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  55%|████████████████             | 273M/492M [00:00<?, ?B/s]
#
# pytorch_model.bin:  28%|█████▌              | 336M/1.22G [00:59<03:03, 4.81MB/s]
#
#
#
# model.safetensors:  64%|█████████████▍       | 315M/492M [00:59<00:39, 4.53MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:   4%|▏   | 73.4M/1.72G [00:09<02:38, 10.4MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   3%|▏        | 94.4M/3.44G [00:10<06:34, 8.48MB/s]
#
#
# pytorch_model.fp16.bin:  69%|███████████     | 419M/608M [00:59<00:45, 4.11MB/s]
#
#
#
#
#
# model.fp16.safetensors:  55%|████████▊       | 336M/608M [00:59<00:34, 7.89MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:   5%|▏   | 83.9M/1.72G [00:10<02:32, 10.7MB/s]
#
#
#
#
# pytorch_model.bin:  55%|███████████▋         | 273M/492M [00:59<00:23, 9.50MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  58%|████████████         | 283M/492M [00:01<00:35, 5.90MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   3%|▎         | 105M/3.44G [00:12<06:47, 8.18MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:   5%|▏   | 94.4M/1.72G [00:11<02:37, 10.3MB/s]
#
#
#
#
#
# model.fp16.safetensors:  57%|█████████       | 346M/608M [01:00<00:34, 7.65MB/s]
# model.safetensors:  38%|███████▌            | 461M/1.22G [01:01<02:25, 5.20MB/s]
#
# pytorch_model.bin:  28%|█████▋              | 346M/1.22G [01:01<03:14, 4.48MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  60%|████████████▌        | 294M/492M [00:02<00:26, 7.54MB/s]
#
#
#
# model.safetensors:  66%|█████████████▊       | 325M/492M [01:02<00:39, 4.20MB/s]
#
#
# pytorch_model.fp16.bin:  71%|███████████▎    | 430M/608M [01:02<00:43, 4.13MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   3%|▎         | 115M/3.44G [00:13<07:21, 7.53MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  62%|████████████▉        | 304M/492M [00:03<00:20, 9.36MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:   6%|▎    | 105M/1.72G [00:13<02:54, 9.25MB/s]
#
#
#
#
#
# model.fp16.safetensors:  59%|█████████▍      | 357M/608M [01:02<00:36, 6.98MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  64%|█████████████▍       | 315M/492M [00:04<00:16, 10.7MB/s]
# model.safetensors:  39%|███████▊            | 472M/1.22G [01:04<02:26, 5.07MB/s]
#
# pytorch_model.bin:  29%|█████▊              | 357M/1.22G [01:04<03:11, 4.49MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  66%|█████████████▊       | 325M/492M [00:05<00:15, 10.7MB/s]
#
#
# pytorch_model.fp16.bin:  72%|███████████▌    | 440M/608M [01:04<00:38, 4.38MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   4%|▎         | 126M/3.44G [00:15<08:08, 6.78MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:   7%|▎    | 115M/1.72G [00:15<03:27, 7.71MB/s]
#
#
#
#
#
# model.fp16.safetensors:  60%|█████████▋      | 367M/608M [01:04<00:35, 6.80MB/s]
# model.safetensors:  40%|███████▉            | 482M/1.22G [01:05<02:14, 5.44MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  68%|██████████████▎      | 336M/492M [00:06<00:15, 10.1MB/s]
#
# pytorch_model.bin:  30%|██████              | 367M/1.22G [01:05<02:51, 4.94MB/s]
#
#
#
#
#
# model.fp16.safetensors:  62%|█████████▉      | 377M/608M [01:05<00:32, 7.16MB/s]
#
#
# pytorch_model.fp16.bin:  74%|███████████▊    | 451M/608M [01:06<00:33, 4.67MB/s]
#
#
#
# model.safetensors:  68%|██████████████▎      | 336M/492M [01:06<00:44, 3.50MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  70%|██████████████▊      | 346M/492M [00:07<00:15, 9.17MB/s]
# model.safetensors:  41%|████████            | 493M/1.22G [01:07<02:05, 5.78MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:   7%|▎    | 126M/1.72G [00:17<04:15, 6.25MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   4%|▍         | 136M/3.44G [00:18<10:08, 5.43MB/s]
#
# pytorch_model.bin:  31%|██████▏             | 377M/1.22G [01:07<02:37, 5.33MB/s]
#
#
#
#
#
# model.fp16.safetensors:  64%|██████████▏     | 388M/608M [01:06<00:30, 7.18MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  72%|███████████████▏     | 357M/492M [00:08<00:13, 10.4MB/s]
#
#
# pytorch_model.fp16.bin:  76%|████████████▏   | 461M/608M [01:08<00:28, 5.07MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  75%|███████████████▋     | 367M/492M [00:09<00:11, 10.8MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:   8%|▍    | 136M/1.72G [00:19<04:19, 6.11MB/s]
# model.safetensors:  41%|████████▎           | 503M/1.22G [01:09<02:08, 5.55MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   4%|▍         | 147M/3.44G [00:20<10:02, 5.46MB/s]
#
#
#
#
#
# model.fp16.safetensors:  66%|██████████▍     | 398M/608M [01:08<00:30, 6.93MB/s]
#
#
# pytorch_model.fp16.bin:  78%|████████████▍   | 472M/608M [01:09<00:24, 5.53MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  77%|████████████████     | 377M/492M [00:10<00:11, 10.2MB/s]
#
# pytorch_model.bin:  32%|██████▍             | 388M/1.22G [01:10<02:53, 4.77MB/s]
#
#
#
# model.safetensors:  70%|██████████████▊      | 346M/492M [01:09<00:44, 3.27MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:   9%|▍    | 147M/1.72G [00:20<04:07, 6.36MB/s]
# model.safetensors:  42%|████████▍           | 514M/1.22G [01:10<01:57, 5.97MB/s]
#
#
#
#
#
# model.fp16.safetensors:  67%|██████████▊     | 409M/608M [01:10<00:28, 6.99MB/s]
#
#
# pytorch_model.fp16.bin:  79%|████████████▋   | 482M/608M [01:11<00:21, 5.79MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  79%|████████████████▌    | 388M/492M [00:12<00:12, 8.33MB/s]
# model.safetensors:  43%|████████▌           | 524M/1.22G [01:11<01:44, 6.65MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:   9%|▍    | 157M/1.72G [00:22<03:58, 6.55MB/s]
#
#
#
# model.safetensors:  72%|███████████████▏     | 357M/492M [01:11<00:36, 3.69MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   5%|▍         | 157M/3.44G [00:23<11:45, 4.65MB/s]
#
#
#
#
#
# model.fp16.safetensors:  69%|███████████     | 419M/608M [01:11<00:27, 6.84MB/s]
#
# pytorch_model.bin:  33%|██████▌             | 398M/1.22G [01:12<02:56, 4.64MB/s]
#
#
# pytorch_model.fp16.bin:  81%|████████████▉   | 493M/608M [01:12<00:18, 6.15MB/s]
# model.safetensors:  44%|████████▊           | 535M/1.22G [01:13<01:34, 7.21MB/s]
#
#
#
#
#
# model.fp16.safetensors:  71%|███████████▎    | 430M/608M [01:12<00:24, 7.13MB/s]
#
#
#
# model.safetensors:  75%|███████████████▋     | 367M/492M [01:13<00:30, 4.14MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   5%|▍         | 168M/3.44G [00:25<11:02, 4.94MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:  10%|▍    | 168M/1.72G [00:24<04:25, 5.85MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  81%|████████████████▉    | 398M/492M [00:15<00:15, 6.13MB/s]
# model.safetensors:  45%|████████▉           | 545M/1.22G [01:14<01:30, 7.45MB/s]
#
# pytorch_model.bin:  34%|██████▋             | 409M/1.22G [01:14<02:44, 4.92MB/s]
#
#
# pytorch_model.fp16.bin:  83%|█████████████▏  | 503M/608M [01:14<00:18, 5.61MB/s]
#
#
#
#
#
# model.fp16.safetensors:  72%|███████████▌    | 440M/608M [01:14<00:22, 7.47MB/s]
#
#
#
# model.safetensors:  77%|████████████████     | 377M/492M [01:14<00:23, 4.84MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   5%|▌         | 178M/3.44G [00:26<10:00, 5.43MB/s]
# model.safetensors:  46%|█████████▏          | 556M/1.22G [01:16<01:34, 7.02MB/s]
#
# pytorch_model.bin:  34%|██████▉             | 419M/1.22G [01:16<02:31, 5.25MB/s]
#
#
#
#
#
# model.fp16.safetensors:  74%|███████████▊    | 451M/608M [01:15<00:20, 7.54MB/s]
#
#
#
# model.safetensors:  79%|████████████████▌    | 388M/492M [01:16<00:18, 5.54MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  83%|█████████████████▍   | 409M/492M [00:17<00:15, 5.38MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   5%|▌         | 189M/3.44G [00:27<09:07, 5.93MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:  10%|▌    | 178M/1.72G [00:27<05:15, 4.89MB/s]
# model.safetensors:  47%|█████████▎          | 566M/1.22G [01:17<01:33, 6.97MB/s]
#
#
#
# model.safetensors:  81%|████████████████▉    | 398M/492M [01:17<00:14, 6.56MB/s]
#
#
# pytorch_model.fp16.bin:  84%|█████████████▌  | 514M/608M [01:17<00:19, 4.90MB/s]
#
# pytorch_model.bin:  35%|███████             | 430M/1.22G [01:18<02:32, 5.16MB/s]
#
#
#
#
#
# model.fp16.safetensors:  76%|████████████▏   | 461M/608M [01:17<00:21, 6.77MB/s]
#
#
#
# model.safetensors:  83%|█████████████████▍   | 409M/492M [01:18<00:11, 7.41MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   6%|▌         | 199M/3.44G [00:29<08:45, 6.17MB/s]
#
#
# pytorch_model.fp16.bin:  86%|█████████████▊  | 524M/608M [01:18<00:15, 5.55MB/s]
# model.safetensors:  47%|█████████▍          | 577M/1.22G [01:19<01:37, 6.55MB/s]
#
# pytorch_model.bin:  36%|███████▏            | 440M/1.22G [01:19<02:13, 5.81MB/s]
#
#
#
# model.safetensors:  85%|█████████████████▉   | 419M/492M [01:19<00:09, 7.77MB/s]
#
#
# pytorch_model.fp16.bin:  88%|██████████████  | 535M/608M [01:20<00:11, 6.31MB/s]
#
#
#
#
#
# model.fp16.safetensors:  78%|████████████▍   | 472M/608M [01:19<00:22, 6.10MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  85%|█████████████████▉   | 419M/492M [00:21<00:17, 4.20MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   6%|▌         | 210M/3.44G [00:31<09:13, 5.83MB/s]
#
# pytorch_model.bin:  37%|███████▍            | 451M/1.22G [01:20<01:59, 6.42MB/s]
#
#
#
# model.safetensors:  87%|██████████████████▎  | 430M/492M [01:20<00:07, 8.44MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:  11%|▌    | 189M/1.72G [00:31<06:23, 3.99MB/s]
#
#
# pytorch_model.fp16.bin:  90%|██████████████▎ | 545M/608M [01:21<00:09, 6.93MB/s]
# model.safetensors:  48%|█████████▋          | 587M/1.22G [01:21<01:46, 5.92MB/s]
#
#
# pytorch_model.fp16.bin:  91%|██████████████▌ | 556M/608M [01:21<00:06, 8.34MB/s]
#
# pytorch_model.bin:  38%|███████▌            | 461M/1.22G [01:22<01:51, 6.76MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  87%|██████████████████▎  | 430M/492M [00:23<00:13, 4.70MB/s]
# model.safetensors:  49%|█████████▊          | 598M/1.22G [01:22<01:34, 6.55MB/s]
#
#
# pytorch_model.fp16.bin:  93%|██████████████▉ | 566M/608M [01:22<00:04, 9.28MB/s]
#
#
#
#
#
# model.fp16.safetensors:  79%|████████████▋   | 482M/608M [01:22<00:24, 5.09MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   6%|▋         | 220M/3.44G [00:34<10:39, 5.03MB/s]
#
# pytorch_model.bin:  39%|███████▊            | 472M/1.22G [01:23<01:48, 6.88MB/s]
# model.safetensors:  50%|██████████          | 608M/1.22G [01:23<01:21, 7.50MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  89%|██████████████████▊  | 440M/492M [00:24<00:10, 5.14MB/s]
#
#
# pytorch_model.fp16.bin:  95%|███████████████▏| 577M/608M [01:23<00:03, 9.33MB/s]
# model.safetensors:  51%|██████████▏         | 619M/1.22G [01:24<01:13, 8.08MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   7%|▋         | 231M/3.44G [00:35<09:41, 5.52MB/s]
#
# pytorch_model.bin:  40%|███████▉            | 482M/1.22G [01:24<01:44, 7.05MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:  12%|▌    | 199M/1.72G [00:35<07:33, 3.35MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  92%|███████████████████▏ | 451M/492M [00:26<00:07, 5.54MB/s]
#
#
# pytorch_model.fp16.bin:  97%|███████████████▍| 587M/608M [01:25<00:02, 8.57MB/s]
#
#
#
#
#
# model.fp16.safetensors:  81%|████████████▉   | 493M/608M [01:24<00:23, 4.84MB/s]
#
#
#
# model.safetensors:  89%|██████████████████▊  | 440M/492M [01:25<00:11, 4.38MB/s]
# model.safetensors:  52%|██████████▎         | 629M/1.22G [01:26<01:15, 7.79MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   7%|▋         | 241M/3.44G [00:37<08:54, 5.98MB/s]
#
# pytorch_model.bin:  41%|████████            | 493M/1.22G [01:26<01:40, 7.23MB/s]
#
#
# pytorch_model.fp16.bin:  98%|███████████████▋| 598M/608M [01:26<00:01, 8.78MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  94%|███████████████████▋ | 461M/492M [00:27<00:05, 5.86MB/s]
#
# pytorch_model.bin:  41%|████████▎           | 503M/1.22G [01:27<01:33, 7.62MB/s]
#
#
# pytorch_model.fp16.bin: 100%|████████████████| 608M/608M [01:27<00:00, 6.94MB/s]
#
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   7%|▋         | 252M/3.44G [00:38<08:18, 6.39MB/s]
# model.safetensors:  53%|██████████▌         | 640M/1.22G [01:27<01:20, 7.17MB/s]
#
#
# diffusion_pytorch_model.fp16.safetensors:   0%|     | 0.00/1.72G [00:00<?, ?B/s]
#
#
#
# model.safetensors:  92%|███████████████████▏ | 451M/492M [01:27<00:09, 4.52MB/s]
#
#
#
#
#
# model.fp16.safetensors:  83%|█████████████▏  | 503M/608M [01:27<00:23, 4.45MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:  12%|▌    | 210M/1.72G [00:38<07:37, 3.30MB/s]
#
#
#
# model.safetensors:  94%|███████████████████▋ | 461M/492M [01:28<00:05, 5.61MB/s]
#
# pytorch_model.bin:  42%|████████▍           | 514M/1.22G [01:28<01:32, 7.62MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   8%|▊         | 262M/3.44G [00:40<08:10, 6.48MB/s]
#
#
# diffusion_pytorch_model.fp16.safetensors:   1%| | 10.5M/1.72G [00:01<04:40, 6.10
#
#
#
# model.safetensors:  96%|████████████████████▏| 472M/492M [01:29<00:03, 6.56MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin:  96%|████████████████████▏| 472M/492M [00:30<00:04, 4.90MB/s]
#
# pytorch_model.bin:  43%|████████▌           | 524M/1.22G [01:30<01:27, 7.88MB/s]
# model.safetensors:  53%|██████████▋         | 650M/1.22G [01:30<01:37, 5.81MB/s]
#
#
#
#
#
# model.fp16.safetensors:  85%|█████████████▌  | 514M/608M [01:29<00:20, 4.54MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   8%|▊         | 273M/3.44G [00:41<08:01, 6.58MB/s]
#
#
#
# model.safetensors:  98%|████████████████████▌| 482M/492M [01:30<00:01, 6.99MB/s]
#
#
# diffusion_pytorch_model.fp16.safetensors:   1%| | 21.0M/1.72G [00:03<04:06, 6.88
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:  13%|▋    | 220M/1.72G [00:41<07:07, 3.51MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   8%|▊         | 283M/3.44G [00:42<07:18, 7.19MB/s]
#
# pytorch_model.bin:  44%|████████▊           | 535M/1.22G [01:31<01:35, 7.10MB/s]
#
#
#
#
#
# model.fp16.safetensors:  86%|█████████████▊  | 524M/608M [01:31<00:16, 5.06MB/s]
#
#
# diffusion_pytorch_model.fp16.safetensors:   2%| | 31.5M/1.72G [00:04<03:35, 7.81
#
#
#
# model.safetensors: 100%|█████████████████████| 492M/492M [01:31<00:00, 5.36MB/s]
#
#
#
#
#
#
#
#
#
# pytorch_model.bin:  98%|████████████████████▌| 482M/492M [00:33<00:02, 4.37MB/s]
#
#
#
# diffusion_pytorch_model.non_ema.bin:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   9%|▊         | 294M/3.44G [00:43<06:44, 7.77MB/s]
#
#
# diffusion_pytorch_model.fp16.safetensors:   2%| | 41.9M/1.72G [00:05<03:27, 8.10
#
#
#
#
#
# model.fp16.safetensors:  88%|██████████████  | 535M/608M [01:32<00:13, 5.58MB/s]
# model.safetensors:  54%|██████████▊         | 661M/1.22G [01:33<01:59, 4.63MB/s]
#
#
#
# diffusion_pytorch_model.non_ema.bin:   0%| | 10.5M/3.44G [00:01<06:56, 8.23MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   9%|▉         | 304M/3.44G [00:45<06:30, 8.02MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:  13%|▋    | 231M/1.72G [00:44<07:12, 3.44MB/s]
#
#
#
#
#
#
#
#
# pytorch_model.bin: 100%|█████████████████████| 492M/492M [00:35<00:00, 6.22MB/s]
# pytorch_model.bin:  55%|███████████▋         | 273M/492M [01:33<01:15, 2.91MB/s]
#
#
# pytorch_model.bin:  45%|████████▉           | 545M/1.22G [01:34<01:54, 5.85MB/s]
#
#
#
#
# (…)fusion_pytorch_model.non_ema.safetensors:   0%|  | 0.00/3.44G [00:00<?, ?B/s]
#
#
#
# diffusion_pytorch_model.non_ema.bin:   1%| | 21.0M/3.44G [00:02<05:23, 10.6MB/s]
#
#
# diffusion_pytorch_model.fp16.safetensors:   3%| | 52.4M/1.72G [00:07<03:49, 7.28
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   9%|▉         | 315M/3.44G [00:46<06:12, 8.39MB/s]
#
#
#
#
#
# model.fp16.safetensors:  90%|██████████████▎ | 545M/608M [01:34<00:11, 5.69MB/s]
#
#
#
# diffusion_pytorch_model.non_ema.bin:   1%| | 31.5M/3.44G [00:02<05:04, 11.2MB/s]
# model.safetensors:  55%|███████████         | 671M/1.22G [01:36<01:59, 4.55MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:   9%|▉         | 325M/3.44G [00:47<06:06, 8.49MB/s]
#
#
#
# diffusion_pytorch_model.non_ema.bin:   1%| | 41.9M/3.44G [00:04<05:22, 10.5MB/s]
#
#
#
#
# (…)fusion_pytorch_model.non_ema.safetensors:   0%| | 10.5M/3.44G [00:02<12:22, 4
#
#
#
#
#
# model.fp16.safetensors:  91%|██████████████▌ | 556M/608M [01:36<00:09, 5.70MB/s]
#
# pytorch_model.bin:  46%|█████████▏          | 556M/1.22G [01:37<02:13, 4.94MB/s]
#
#
# diffusion_pytorch_model.fp16.safetensors:   4%| | 62.9M/1.72G [00:09<04:29, 6.14
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:  14%|▋    | 241M/1.72G [00:47<07:14, 3.40MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:  10%|▉         | 336M/3.44G [00:48<05:50, 8.84MB/s]
# model.safetensors:  56%|███████████▏        | 682M/1.22G [01:38<01:51, 4.78MB/s]
#
#
#
# diffusion_pytorch_model.non_ema.bin:   2%| | 52.4M/3.44G [00:05<06:10, 9.14MB/s]
#
#
#
#
#
# model.fp16.safetensors:  93%|██████████████▉ | 566M/608M [01:37<00:06, 6.32MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:  15%|▋    | 252M/1.72G [00:49<06:10, 3.97MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:  10%|█         | 346M/3.44G [00:50<06:23, 8.06MB/s]
#
#
# diffusion_pytorch_model.fp16.safetensors:   4%| | 73.4M/1.72G [00:11<04:32, 6.03
#
# pytorch_model.bin:  47%|█████████▎          | 566M/1.22G [01:39<02:09, 5.01MB/s]
#
#
#
#
# (…)fusion_pytorch_model.non_ema.safetensors:   1%| | 21.0M/3.44G [00:04<13:07, 4
#
#
#
#
#
# model.fp16.safetensors:  95%|███████████████▏| 577M/608M [01:39<00:04, 6.38MB/s]
#
#
#
# diffusion_pytorch_model.non_ema.bin:   2%| | 62.9M/3.44G [00:07<07:27, 7.55MB/s]
# model.safetensors:  57%|███████████▍        | 692M/1.22G [01:40<01:48, 4.85MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:  10%|█         | 357M/3.44G [00:51<06:37, 7.76MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:  15%|▊    | 262M/1.72G [00:51<05:28, 4.44MB/s]
#
#
# diffusion_pytorch_model.fp16.safetensors:   5%| | 83.9M/1.72G [00:12<04:30, 6.05
#
#
#
#
# (…)fusion_pytorch_model.non_ema.safetensors:   1%| | 31.5M/3.44G [00:06<11:18, 5
#
# pytorch_model.bin:  47%|█████████▍          | 577M/1.22G [01:41<02:05, 5.09MB/s]
# model.safetensors:  58%|███████████▌        | 703M/1.22G [01:41<01:33, 5.49MB/s]
#
#
#
#
#
# model.fp16.safetensors:  97%|███████████████▍| 587M/608M [01:41<00:03, 5.90MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:  11%|█         | 367M/3.44G [00:53<06:52, 7.44MB/s]
#
#
#
#
# (…)fusion_pytorch_model.non_ema.safetensors:   1%| | 41.9M/3.44G [00:07<09:43, 5
#
#
#
# diffusion_pytorch_model.non_ema.bin:   2%| | 73.4M/3.44G [00:09<09:22, 5.98MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:  16%|▊    | 273M/1.72G [00:53<05:15, 4.58MB/s]
#
# pytorch_model.bin:  48%|█████████▋          | 587M/1.22G [01:43<01:57, 5.35MB/s]
#
#
#
#
# (…)fusion_pytorch_model.non_ema.safetensors:   2%| | 52.4M/3.44G [00:08<07:21, 7
# model.safetensors:  59%|███████████▋        | 713M/1.22G [01:43<01:30, 5.53MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:  11%|█         | 377M/3.44G [00:54<07:06, 7.18MB/s]
#
#
#
#
# (…)fusion_pytorch_model.non_ema.safetensors:   2%| | 62.9M/3.44G [00:09<06:09, 9
#
#
#
# diffusion_pytorch_model.non_ema.bin:   2%| | 83.9M/3.44G [00:11<09:09, 6.10MB/s]
#
#
# diffusion_pytorch_model.fp16.safetensors:   5%| | 94.4M/1.72G [00:16<05:54, 4.58
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:  16%|▊    | 283M/1.72G [00:54<04:47, 5.00MB/s]
#
#
#
#
# (…)fusion_pytorch_model.non_ema.safetensors:   2%| | 73.4M/3.44G [00:10<05:38, 9
#
# pytorch_model.bin:  49%|█████████▊          | 598M/1.22G [01:45<01:55, 5.38MB/s]
# model.safetensors:  60%|███████████▉        | 724M/1.22G [01:45<01:29, 5.53MB/s]
#
#
#
# diffusion_pytorch_model.non_ema.bin:   3%| | 94.4M/3.44G [00:12<08:27, 6.59MB/s]
#
#
#
#
# (…)fusion_pytorch_model.non_ema.safetensors:   2%| | 83.9M/3.44G [00:10<05:28, 1
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:  11%|█▏        | 388M/3.44G [00:56<07:54, 6.42MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:  17%|▊    | 294M/1.72G [00:56<04:22, 5.44MB/s]
#
#
#
#
#
# model.fp16.safetensors:  98%|███████████████▋| 598M/608M [01:45<00:02, 4.26MB/s]
# model.safetensors:  60%|████████████        | 734M/1.22G [01:46<01:18, 6.12MB/s]
#
#
#
# diffusion_pytorch_model.non_ema.bin:   3%|  | 105M/3.44G [00:14<07:54, 7.02MB/s]
#
# pytorch_model.bin:  50%|██████████          | 608M/1.22G [01:47<01:53, 5.35MB/s]
#
#
#
#
# (…)fusion_pytorch_model.non_ema.safetensors:   3%| | 94.4M/3.44G [00:12<05:56, 9
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:  18%|▉    | 304M/1.72G [00:57<03:59, 5.90MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:  12%|█▏        | 398M/3.44G [00:58<08:19, 6.08MB/s]
# model.safetensors:  61%|████████████▏       | 744M/1.22G [01:48<01:14, 6.35MB/s]
#
#
#
# diffusion_pytorch_model.non_ema.bin:   3%|  | 115M/3.44G [00:15<07:42, 7.18MB/s]
#
#
#
#
#
# model.fp16.safetensors: 100%|████████████████| 608M/608M [01:47<00:00, 5.64MB/s]
# Fetching 29 files:  14%|███▍                     | 4/29 [01:49<12:17, 29.49s/it]
#
# pytorch_model.bin:  51%|██████████▏         | 619M/1.22G [01:48<01:48, 5.53MB/s]
#
#
#
#
# (…)fusion_pytorch_model.non_ema.safetensors:   3%| | 105M/3.44G [00:14<07:04, 7.
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:  12%|█▏        | 409M/3.44G [00:59<07:34, 6.66MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:  18%|▉    | 315M/1.72G [00:59<03:45, 6.24MB/s]
#
#
# diffusion_pytorch_model.fp16.safetensors:   6%| | 105M/1.72G [00:20<07:40, 3.51M
# model.safetensors:  62%|████████████▍       | 755M/1.22G [01:49<01:08, 6.77MB/s]
#
#
#
#
#
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
#
#
#
# diffusion_pytorch_model.non_ema.bin:   4%|  | 126M/3.44G [00:17<08:22, 6.59MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.bin:  12%|█▏        | 419M/3.44G [01:01<07:10, 7.02MB/s]
#
# pytorch_model.bin:  52%|██████████▎         | 629M/1.22G [01:50<01:39, 5.88MB/s]
# model.safetensors:  63%|████████████▌       | 765M/1.22G [01:50<00:59, 7.58MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.bin:  19%|▉    | 325M/1.72G [01:00<03:39, 6.35MB/s]
#
#
#
#
# (…)fusion_pytorch_model.non_ema.safetensors:   3%| | 115M/3.44G [00:16<08:56, 6.
#
#
# diffusion_pytorch_model.fp16.safetensors:   7%| | 115M/1.72G [00:23<07:11, 3.72M
#
#
#
#
#
# diffusion_pytorch_model.safetensors:   0%| | 10.5M/3.44G [00:01<08:10, 6.99MB/s]
# model.safetensors:  64%|████████████▊       | 776M/1.22G [01:51<00:54, 8.10MB/s]
#
#
#
#
#
#
#
# ...
#
#
#
# diffusion_pytorch_model.non_ema.bin:  98%|▉| 3.36G/3.44G [06:25<00:04, 18.3MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  93%|▉| 3.20G/3.44G [03:38<00:14, 1
# (…)fusion_pytorch_model.non_ema.safetensors:  93%|▉| 3.21G/3.44G [03:38<00:13, 1
#
#
#
# diffusion_pytorch_model.non_ema.bin:  98%|▉| 3.37G/3.44G [06:26<00:04, 17.7MB/s]
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  92%|▉| 3.18G/3.44G [06:09<00:25, 10.4MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  94%|▉| 3.22G/3.44G [03:39<00:13, 1
#
#
#
# diffusion_pytorch_model.non_ema.bin:  98%|▉| 3.38G/3.44G [06:26<00:03, 17.1MB/s]
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  93%|▉| 3.19G/3.44G [06:10<00:21, 11.4MB/s]
#
#
#
# diffusion_pytorch_model.non_ema.bin:  99%|▉| 3.39G/3.44G [06:27<00:02, 17.3MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  94%|▉| 3.23G/3.44G [03:39<00:12, 1
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  93%|▉| 3.20G/3.44G [06:10<00:20, 11.9MB/s]
#
#
#
# diffusion_pytorch_model.non_ema.bin:  99%|▉| 3.40G/3.44G [06:28<00:02, 17.3MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  94%|▉| 3.24G/3.44G [03:40<00:12, 1
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  93%|▉| 3.21G/3.44G [06:11<00:17, 12.8MB/s]
#
#
#
# diffusion_pytorch_model.non_ema.bin:  99%|▉| 3.41G/3.44G [06:28<00:01, 16.4MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  95%|▉| 3.25G/3.44G [03:41<00:11, 1
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  94%|▉| 3.22G/3.44G [06:12<00:16, 13.0MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  95%|▉| 3.26G/3.44G [03:41<00:10, 1
#
#
#
# diffusion_pytorch_model.non_ema.bin:  99%|▉| 3.42G/3.44G [06:29<00:01, 15.4MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  95%|▉| 3.27G/3.44G [03:42<00:09, 1
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  94%|▉| 3.23G/3.44G [06:13<00:15, 13.2MB/s]
#
#
#
# diffusion_pytorch_model.non_ema.bin: 100%|▉| 3.43G/3.44G [06:30<00:00, 14.1MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  95%|▉| 3.28G/3.44G [03:42<00:08, 1
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  94%|▉| 3.24G/3.44G [06:13<00:14, 14.1MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  96%|▉| 3.29G/3.44G [03:43<00:08, 1
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  95%|▉| 3.25G/3.44G [06:14<00:12, 15.1MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  96%|▉| 3.30G/3.44G [03:44<00:07, 1
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  95%|▉| 3.26G/3.44G [06:14<00:10, 16.8MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  96%|▉| 3.31G/3.44G [03:44<00:06, 2
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  95%|▉| 3.27G/3.44G [06:15<00:09, 18.3MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  97%|▉| 3.32G/3.44G [03:44<00:05, 2
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  95%|▉| 3.28G/3.44G [06:15<00:08, 19.5MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  97%|▉| 3.33G/3.44G [03:45<00:04, 2
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  96%|▉| 3.29G/3.44G [06:16<00:07, 20.6MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  97%|▉| 3.34G/3.44G [03:45<00:04, 2
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  96%|▉| 3.30G/3.44G [06:16<00:07, 19.2MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  98%|▉| 3.36G/3.44G [03:46<00:04, 1
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  96%|▉| 3.31G/3.44G [06:17<00:06, 20.5MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  98%|▉| 3.37G/3.44G [03:46<00:03, 2
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  97%|▉| 3.32G/3.44G [06:17<00:05, 21.3MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  98%|▉| 3.38G/3.44G [03:47<00:02, 2
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  97%|▉| 3.33G/3.44G [06:18<00:04, 22.1MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  99%|▉| 3.39G/3.44G [03:47<00:02, 2
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  97%|▉| 3.34G/3.44G [06:18<00:04, 22.0MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  99%|▉| 3.40G/3.44G [03:48<00:01, 2
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  98%|▉| 3.36G/3.44G [06:18<00:03, 22.2MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  99%|▉| 3.41G/3.44G [03:48<00:01, 2
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  98%|▉| 3.37G/3.44G [06:19<00:03, 21.9MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors:  99%|▉| 3.42G/3.44G [03:49<00:00, 2
# (…)fusion_pytorch_model.non_ema.safetensors: 100%|▉| 3.43G/3.44G [03:49<00:00, 2
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  98%|▉| 3.38G/3.44G [06:20<00:02, 20.8MB/s]
# (…)fusion_pytorch_model.non_ema.safetensors: 100%|█| 3.44G/3.44G [03:49<00:00, 1
# (…)fusion_pytorch_model.non_ema.safetensors:  27%|▎| 944M/3.44G [06:35<17:25, 2.
#
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  99%|▉| 3.39G/3.44G [06:20<00:02, 22.5MB/s]
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  99%|▉| 3.40G/3.44G [06:20<00:01, 26.8MB/s]
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  99%|▉| 3.41G/3.44G [06:20<00:00, 30.8MB/s]
#
#
#
#
#
# diffusion_pytorch_model.safetensors:  99%|▉| 3.42G/3.44G [06:21<00:00, 34.3MB/s]
#
#
#
#
#
# diffusion_pytorch_model.safetensors: 100%|▉| 3.43G/3.44G [06:21<00:00, 37.0MB/s]
#
#
#
#
#
# diffusion_pytorch_model.safetensors: 100%|█| 3.44G/3.44G [06:21<00:00, 9.01MB/s]
# Error while downloading from https://cdn-lfs.huggingface.co/repos/6b/20/6b201da5f0f5c60524535ebb7deac2eef68605655d3bbacfee9cce0087f3b3f5/42bc8b8f3af32866db3c7bb5bcf591ab04438296c2712246d7a640bde5a5ddc1?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27diffusion_pytorch_model.non_ema.bin%3B+filename%3D%22diffusion_pytorch_model.non_ema.bin%22%3B&response-content-type=application%2Foctet-stream&Expires=1702561477&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=u848ZTLnaH1f47vCerWqu3DuSgPUQIS6--E1KKutW8z1p7KABMoHW1ILH%7EMNOG7fH7p5iryb0rxsX-NPzo2SVG7MrWDPbbUlEMwQxBgr-A%7EFXBiS6cy%7Ei9LmkOLgtHFas%7E-z3V1ozAJZ386eB%7Ey52kEEklC9naOGf75bsISng6gmuxR3JXmlvY8evNy66Ho9aYm73-EW4AYjV9UT5YJC1vIWVyPHQvQW034xFK8o-3dInraIHaQgwxJtD4L7jn9L0EJ1aP0fR1KgQEEchNkQDcQ3JC3ZaInMtuVJSwLkMfnIPKfrnX%7EXsF6OoyEkQBIS%7EsqkQx1dhmnPxpcswlDgdg__&Key-Pair-Id=KVTP0A1DKRTAX: HTTPSConnectionPool(host='cdn-lfs.huggingface.co', port=443): Read timed out.
# Trying to resume download...
#
# diffusion_pytorch_model.non_ema.bin: 100%|████████▉| 3.43G/3.44G [00:00<?, ?B/s]
# diffusion_pytorch_model.non_ema.bin: 100%|█| 3.44G/3.44G [00:00<00:00, 42.8MB/s]
# diffusion_pytorch_model.non_ema.bin: 100%|▉| 3.43G/3.44G [06:43<00:01, 8.50MB/s]
# Fetching 29 files: 100%|████████████████████████| 29/29 [08:16<00:00, 17.13s/it]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# Generating class images: 100%|████████████| 1500/1500 [1:54:12<00:00,  4.57s/it]
# tokenizer/vocab.json: 100%|████████████████| 1.06M/1.06M [00:00<00:00, 1.33MB/s]
# tokenizer/merges.txt: 100%|███████████████████| 525k/525k [00:00<00:00, 875kB/s]
# tokenizer/special_tokens_map.json: 100%|████████| 472/472 [00:00<00:00, 437kB/s]
# tokenizer/tokenizer_config.json: 100%|██████████| 806/806 [00:00<00:00, 778kB/s]
# text_encoder/config.json: 100%|█████████████████| 617/617 [00:00<00:00, 351kB/s]
# model.safetensors: 100%|█████████████████████| 492M/492M [00:09<00:00, 49.9MB/s]
# Could not enable memory efficient attention. Make sure xformers is installed correctly and a GPU is available: No operator found for `memory_efficient_attention_forward` with inputs:
#      query       : shape=(1, 2, 1, 40) (torch.float32)
#      key         : shape=(1, 2, 1, 40) (torch.float32)
#      value       : shape=(1, 2, 1, 40) (torch.float32)
#      attn_bias   : <class 'NoneType'>
#      p           : 0.0
# `decoderF` is not supported because:
#     xFormers wasn't build with CUDA support
#     attn_bias type is <class 'NoneType'>
#     operator wasn't built - see `python -m xformers.info` for more info
# `flshattF@0.0.0` is not supported because:
#     xFormers wasn't build with CUDA support
#     dtype=torch.float32 (supported: {torch.bfloat16, torch.float16})
#     operator wasn't built - see `python -m xformers.info` for more info
# `tritonflashattF` is not supported because:
#     xFormers wasn't build with CUDA support
#     dtype=torch.float32 (supported: {torch.bfloat16, torch.float16})
#     operator wasn't built - see `python -m xformers.info` for more info
#     triton is not available
#     Only work on pre-MLIR triton for now
# `cutlassF` is not supported because:
#     xFormers wasn't build with CUDA support
#     operator wasn't built - see `python -m xformers.info` for more info
# `smallkF` is not supported because:
#     max(query.shape[-1] != value.shape[-1]) > 32
#     xFormers wasn't build with CUDA support
#     operator wasn't built - see `python -m xformers.info` for more info
#     unsupported embed per head: 40
#
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link
# ================================================================================
# /home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages/bitsandbytes/cuda_setup/paths.py:93: UserWarning: /home/nas4_user/saemeechoi/anaconda3/envs/tokenflow did not contain libcudart.so as expected! Searching further paths...
#   warn(
# /home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/run/user/1000065/vscode-ipc-8ce310f1-0fcc-4fe7-94f5-9c8d791b4172.sock')}
#   warn(
# /home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('module'), PosixPath('//matplotlib_inline.backend_inline')}
#   warn(
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 8.6
# CUDA SETUP: Detected CUDA version 110
# CUDA SETUP: Loading binary /home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages/bitsandbytes/libbitsandbytes_cuda110.so...
# ***** Running training *****
#   Num examples = 2197
#   Num batches each epoch = 2197
#   Num Epochs = 5
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 1
#   Gradient Accumulation steps = 1
#   Total optimization steps = 10000
# Steps:   0%|                                          | 0/10000 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/home/nas4_user/saemeechoi/course/AdvancedDeepLearning/notebooks/content/Dreambooth/train.py", line 1112, in <module>
#     main(args)
#   File "/home/nas4_user/saemeechoi/course/AdvancedDeepLearning/notebooks/content/Dreambooth/train.py", line 1005, in main
#     for step, batch in enumerate(train_dataloader):
#   File "/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages/accelerate/data_loader.py", line 375, in __iter__
#     current_batch = next(dataloader_iter)
#   File "/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 633, in __next__
#     data = self._next_data()
#   File "/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1345, in _next_data
#     return self._process_data(data)
#   File "/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1371, in _process_data
#     data.reraise()
#   File "/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages/torch/_utils.py", line 644, in reraise
#     raise exception
# ZeroDivisionError: Caught ZeroDivisionError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages/torch/utils/data/_utils/worker.py", line 308, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/nas4_user/saemeechoi/course/AdvancedDeepLearning/notebooks/content/Dreambooth/train.py", line 398, in __getitem__
#     image_path = self.instance_images_path[index % self.num_instance_images]
# ZeroDivisionError: integer division or modulo by zero
#
# Steps:   0%|                                          | 0/10000 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/bin/accelerate", line 8, in <module>
#     sys.exit(main())
#   File "/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages/accelerate/commands/accelerate_cli.py", line 45, in main
#     args.func(args)
#   File "/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages/accelerate/commands/launch.py", line 1104, in launch_command
#     simple_launcher(args)
#   File "/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/lib/python3.9/site-packages/accelerate/commands/launch.py", line 567, in simple_launcher
#     raise subprocess.CalledProcessError(returncode=process.returncode, cmd=cmd)
# subprocess.CalledProcessError: Command '['/home/nas4_user/saemeechoi/anaconda3/envs/tokenflow/bin/python', 'content/Dreambooth/train.py', '--lora_rank=4', '--pretrained_model_name_or_path=runwayml/stable-diffusion-v1-5', '--pretrained_vae_name_or_path=', '--instance_data_dir=content/InstanceImages', '--class_data_dir=content/RegularizationImages', '--output_dir=content/models/', '--logging_dir=content/logs/', '--log_gpu', '--with_prior_preservation', '--prior_loss_weight=1.0', '--instance_prompt=a photo of raretoken person', '--class_prompt=a photo of a person', '--conditioning_dropout_prob=0.0', '--unconditional_prompt= ', '--seed=1275017', '--resolution=512', '--train_batch_size=1', '--gradient_accumulation_steps=1', '--gradient_checkpointing', '--mixed_precision=fp16', '--use_8bit_adam', '--adam_beta1=0.9', '--adam_beta2=0.999', '--adam_weight_decay=0.01', '--adam_epsilon=1e-08', '--learning_rate=2e-06', '--learning_rate_text=5e-05', '--lr_scheduler=cosine', '--lr_warmup_steps=50', '--lr_cosine_num_cycles=5', '--ema_inv_gamma=1.0', '--ema_power=0.75', '--ema_min_value=0', '--ema_max_value=0.9999', '--max_train_steps=10000', '--num_class_images=1500', '--sample_batch_size=1', '--save_min_steps=500', '--save_interval=500', '--n_save_sample=2', '--save_sample_prompt=a photo of raretoken // a painting of raretoken person by Picasso', '--save_sample_negative_prompt=border', '--augment_center_crop']' returned non-zero exit status 1.

# %% [markdown]
# # Do inference with trained model(s)
#
# Cells in this section can be run to generate grids of images using the trained model(s). I find this useful for probing overtraining, concept bleeding, quality, etc.

# %%
#@title Some imports and utility functions
import torch
from diffusers import DiffusionPipeline, StableDiffusionPipeline, DPMSolverMultistepScheduler, AutoencoderKL
from PIL import Image
import os
import json
import random
import string
from lora_diffusion import monkeypatch_lora, tune_lora_scale

device = "cuda"

def image_grid(imgs, rows, cols):
    assert len(imgs) == rows*cols
    w, h = imgs[0].size
    grid = Image.new('RGB', size=(cols*w, rows*h))
    grid_w, grid_h = grid.size
    for i, img in enumerate(imgs):
        grid.paste(img, box=(i%cols*w, i//cols*h))
    return grid

def get_pipeline(model_name_or_path,
                 vae_name_or_path=None,
                 text_encoder_name_or_path=None,
                 feature_extractor_name_or_path=None,
                 revision="fp16"):
    #scheduler = DPMSolverMultistepScheduler.from_pretrained(model_name_or_path, subfolder="scheduler")
    scheduler = DPMSolverMultistepScheduler(
        beta_start=0.00085,
        beta_end=0.012,
        beta_schedule="scaled_linear",
        num_train_timesteps=1000,
        trained_betas=None,
        prediction_type="epsilon",
        thresholding=False,
        algorithm_type="dpmsolver++",
        solver_type="midpoint",
        lower_order_final=True,
    )

    pipe = DiffusionPipeline.from_pretrained(
        model_name_or_path,
        custom_pipeline="lpw_stable_diffusion",
        safety_checker=None,
        revision=revision,
        scheduler=scheduler,
        vae=AutoencoderKL.from_pretrained(
            vae_name_or_path or model_name_or_path,
            subfolder=None if vae_name_or_path else "vae",
            revision=None if vae_name_or_path else revision,
            torch_dtype=torch.float16,
        ),
        feature_extractor=feature_extractor_name_or_path,
        torch_dtype=torch.float16
    ).to("cuda")

    #https://github.com/huggingface/diffusers/issues/1552
    #pipe.enable_attention_slicing()
    pipe.enable_xformers_memory_efficient_attention()
    return pipe

# Monkey patch LoRA pt files
# Returns pipeline
def get_lora_pipeline(model_dir, scale_unet=1.0, scale_text_encoder=1.0):
    # Load untrained original model
    pipe = get_pipeline(MODEL_NAME_OR_PATH, vae_name_or_path=VAE_NAME_OR_PATH)

    print('Monkey patching unet pt file')
    monkeypatch_lora(pipe.unet, torch.load(os.path.join(model_dir, "lora_unet.pt")))

    print('Monkey patching text encoder pt file')
    monkeypatch_lora(pipe.text_encoder, torch.load(os.path.join(model_dir, "lora_text_encoder.pt")), target_replace_module=["CLIPAttention"])

    tune_lora_scale(pipe.unet, scale_unet)
    tune_lora_scale(pipe.text_encoder, scale_text_encoder)

    return pipe

def get_config(filename=None,
               save_dir=None,
               prompt=None, negative_prompt=None,
               seeds=None,
               num_samples=4,
               width=512, height=512,
               inference_steps=20,
               guidance_scale=7.5,
               ):
    if filename==None:
        num_prompts = len(prompt)
        if seeds==None:
            seeds = []
            # fixed value seeds for easier comparision betwen subsequent runs/config files
            for i in range(num_samples):
                seeds.append(i * 1000000)
        else:
            num_samples = len(seeds)

        tag = ''.join(random.choice(string.ascii_letters) for _ in range(8))
        config = {
            "tag": tag,
            "prompt": prompt,
            "negative_prompt": negative_prompt,
            "num_prompts": num_prompts,
            "num_samples": num_samples,
            "seeds": seeds,
            "height": height,
            "width": width,
            "inference_steps": inference_steps,
            "guidance_scale": guidance_scale,
        }

        with open(os.path.join(save_dir, "config_"+tag+".json"), "w") as outfile:
            json.dump(config, outfile)
    else:
        f = open(filename)
        config = json.load(f)

    return config

def get_images(pipe, sample_config, device="cuda"):
    generator = torch.Generator("cuda")
    with torch.autocast(device):
        num_cfg = len(sample_config['guidance_scale'])
        # Loop in order to use defined seed for each image in a batch
        all_images = []
        for i in range(sample_config['num_samples']):
        #for _ in sample_config['num_samples']:
            for cfg in sample_config['guidance_scale']:
                # Manually generate latent
                seed = sample_config['seeds'][i]
                generator = generator.manual_seed(seed)
                latent = torch.randn(
                    (1, pipe.unet.in_channels, sample_config['height'] // 8, sample_config['width'] // 8),
                    generator = generator,
                    device = device
                )
                images = pipe(sample_config['prompt'],
                    negative_prompt=sample_config['negative_prompt'],
                    num_inference_steps=int(sample_config['inference_steps']),
                    guidance_scale=cfg,
                    latents=latent.repeat(sample_config['num_prompts'], 1, 1, 1),
                ).images
                all_images.extend(images)

    grid = image_grid(all_images, rows=num_cfg*sample_config['num_samples'], cols=sample_config['num_prompts'])
    return grid

# %%
#@title Specify which models to do inference with
model_list = [os.path.join(OUTPUT_DIR,'500'),
              os.path.join(OUTPUT_DIR,'1000'),
              os.path.join(OUTPUT_DIR,'2500'),
              ]

print(model_list)
# Out:
# ['/content/models/500', '/content/models/1000', '/content/models/2500']

# %%
#@title Generate or load a configuration for inference

config_name = None
#config_name = os.path.join(OUTPUT_DIR, "config_ZMasiqkP.json")

if config_name is None:
    num_samples = 6
    prompt = ["photo of a cat",
              "photo of a person",
              "close-up studio portrait photo of Keanu Reeves, film, detail, studio lighting",
              "close-up studio portrait photo of {SKS} person, film, detail, studio lighting",
              "beautiful white (marble:1.1) bust of {SKS} person, highly detailed",
              "oil painting of {SKS} person on the beach",
    ]
    negative_prompt = "hands, nude, nudity, duplicate, frame, border"
    guidance_scale = [1.0, 3.0, 7.0, 15.0]

    config = get_config(save_dir=OUTPUT_DIR,
                        prompt=prompt, negative_prompt=negative_prompt,
                        num_samples=num_samples,
                        width=512, height=512,
                        inference_steps=20, guidance_scale=guidance_scale
                        )
else:
    config = get_config(filename=config_name)

config['prompt'] = [sub.replace('{SKS}', INSTANCE_TOKEN) for sub in config['prompt']]
print(config)

# %%
#@title Infer!

LORA_SCALE_UNET = 1.0 #@param {type:"slider", min:0.0, max:2.0}
LORA_SCALE_TENC = 1.0 #@param {type:"slider", min:0.0, max:2.0}

for model in model_list:
    print(model)
    pipe = get_pipeline(model) if not USE_LORA else get_lora_pipeline(model, scale_unet=LORA_SCALE_UNET, scale_text_encoder=LORA_SCALE_TENC)
    grid = get_images(pipe, config)
    grid.save(os.path.join(OUTPUT_DIR, "grid_"+os.path.split(model)[1]+"_"+config['tag']+".jpg"), quality=90, optimize=True)
    del pipe
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

# %%
#@title Generate grids for base model using same config
model_name_or_path = MODEL_NAME_OR_PATH #'runwayml/stable-diffusion-v1-5'
vae_name_or_path = VAE_NAME_OR_PATH #'stabilityai/sd-vae-ft-mse'
pipe = get_pipeline(model_name_or_path, vae_name_or_path=vae_name_or_path)
grid = get_images(pipe, config)
grid.save(os.path.join(OUTPUT_DIR, "grid_"+os.path.split(model_name_or_path)[1]+"_"+config['tag']+".jpg"), quality=90, optimize=True)

del pipe
if torch.cuda.is_available():
    torch.cuda.empty_cache()

# %% [markdown]
# # Convert to checkpoint (ckpt) format

# %%
# !wget -q https://raw.githubusercontent.com/huggingface/diffusers/main/scripts/convert_diffusers_to_original_stable_diffusion.py

MODEL_PATH = os.path.join(OUTPUT_DIR, '500')
CKPT_PATH = os.path.join(OUTPUT_DIR, '500.ckpt')

# !python content/convert_diffusers_to_original_stable_diffusion.py \
  --model_path $MODEL_PATH \
  --checkpoint_path $CKPT_PATH \
  --half

# %% [markdown]
# # Close Colab instance

# %%
# from google.colab import runtime
# runtime.unassign()
